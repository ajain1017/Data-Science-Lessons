# %% [markdown]
# ## <center> K-Nearest Neighbors (KNN)
# ## <center> and
# ## <center> Support Vector Machines (SVM)

# %% [markdown]
# ## <center> KNN

# %% [markdown]
# <center><img src='knn_anim.gif'>

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
from sklearn.datasets import make_blobs,make_classification
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import numpy as np
X,y = make_classification(n_samples=100, n_features=2, n_classes=2, n_redundant=0, class_sep=0.25, hypercube=50, random_state=4)
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.05)

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.scatter(np.hstack((X_train[:,0],X_test[:,0])), np.hstack((X_train[:,1], X_test[:,1])), 
            c=np.hstack((y_train,[2]*len(y_test))), cmap='Paired', s=250)

# %%
knn = KNeighborsClassifier(n_neighbors=5).fit(X_train,y_train)
y_pred = knn.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
print('Actual')
print(y_test)
print('Predicted')
print(y_pred)
accuracy_score(y_test, y_pred)
# Out:
# Actual
# [0 1 0 1 1]
# Predicted
# [0 0 0 1 0]
# 0.6

# %%
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
h = .05
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))
Z = knn.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)
plt.figure()
plt.pcolormesh(xx, yy, Z, cmap='coolwarm', alpha=.8)
plt.scatter(X[:,0],X[:,1],c=y)

# %%
scores = [accuracy_score(y_test, KNeighborsClassifier(n_neighbors=k).fit(X_train,y_train).predict(X_test)) for k in range(1,30)]
plt.plot([k for k in range(1,30)], scores)
plt.xlabel('k');plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %% [markdown]
# ## <center> SVM

# %% [markdown]
# <center><img src="supportvectors.png">

# %% [markdown]
# <center><img src="supportvectors2.png">

# %% [markdown]
# ## <center> Regularization
# <center>How much you want to avoid misclassifying.

# %% [markdown]
# Low regularization value
# <center><img src='low_regular.png'>

# %% [markdown]
# High regularization value
# <center><img src='high_regular.png'>

# %% [markdown]
# ## <center> Gamma
# <center> How much close/far away points should be considered.

# %% [markdown]
# <center><img src="low_gamma.png">

# %% [markdown]
# <center><img src="high_gamma.png">

# %% [markdown]
# ## <center> Margin
# <center>The amount of seperation between the hyperplane and the support vectors.

# %% [markdown]
# <center><img src="support_vectors.jpg">

# %% [markdown]
# ## <center> Kernels
# <center> Feature transformations that allow classes to be more easily seperated.

# %% [markdown]
# <center><img src="kernel.png">

# %% [markdown]
# ## <center> Kernel Options

# %% [markdown]
# <center><a href="https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html">Sklearn SVM documentation</a>

# %%
from sklearn.datasets import make_circles
X,y = make_circles(n_samples=1000, noise=0.05, random_state=4)
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.05)
fig, ax = plt.subplots(figsize=(10,10))
ax.scatter(np.hstack((X_train[:,0],X_test[:,0])), np.hstack((X_train[:,1], X_test[:,1])), 
            c=np.hstack((y_train,[2]*len(y_test))), cmap='Paired', s=250)

# %%
from sklearn.svm import SVC
svm = SVC(kernel='linear').fit(X_train, y_train)
print('Linear Kernel')
print('Acc:', accuracy_score(y_test,svm.predict(X_test)))
# Out:
# Linear Kernel
# Acc: 0.36

# %%
svm = SVC(kernel='rbf').fit(X_train, y_train)
print('RBF Kernel')
print('Acc:', accuracy_score(y_test,svm.predict(X_test)))
# Out:
# RBF Kernel
# Acc: 0.94

# %% [markdown]
# ## <center> Classification Methods Guide </center>
# <center> When to use each algorithm </center>
#
# <b>Logistic Regression:</b>
# - Binary classification
#
# <b>KNN:</b>
# - Low-medium number of data points (<10000)
# - Not many features
#
# <b>SVM:</b>
# - Low-medium number of data points
# - High dimensional data (many features)
#
# <b>Random Forest:</b>
# - Lots of categorical features
# - High number of data points (>10000)
# - High dimensional data

# %% [markdown]
# ## <center> Activity
# <center> Using the data in <i>clf_data.csv</i>, build a classification model.

# %% [markdown]
# <b>1)</b> Load in the data and perform a train-test split with a test size of 0.15 and set the random state to 4.

# %%
import pandas as pd
df = pd.read_csv("clf_data.csv")
display(df.head())
X_train, X_test, y_train, y_test = train_test_split(df.drop('Class', axis=1),df['Class'],test_size=0.15, random_state = 4)
# Out:
#          X0        X1        X2        X3        X4        X5        X6  \
# 0 -0.962300  0.608462  0.097724  0.353696 -0.391590 -0.095559  1.164383
# 1 -0.805601  1.453629  0.418794 -1.039750 -0.070696  1.716998 -1.436549
# 2 -0.965587  1.982762 -0.367578  0.752049 -0.443615 -0.582216 -0.590020
# 3 -1.150379 -0.786927  0.149566 -0.004063 -0.511172 -0.429024  0.733399
# 4  0.837504  0.790625 -0.413361  1.727582 -0.011984 -0.174280 -0.301600
#
#          X7        X8        X9  ...         X91       X92       X93  \
# 0  1.049200 -0.904335 -0.718082  ...   -0.561098  0.556241  0.067288
# 1  0.518250  0.263587 -0.288619  ...   -0.933484 -0.299918 -0.517144
# 2 -2.169655 -0.248272 -0.801674  ...   -0.988912 -0.705771 -0.926195
# 3  0.086393  1.254542 -0.038435  ...   -1.823939 -1.510152 -1.270717
# 4  0.787086 -1.700692  1.119873  ...   -0.123756  0.950671  0.640373
#
#         X94       X95       X96       X97       X98       X99  Class
# 0  1.742920 -0.245225  0.087718 -0.106110 -0.029192 -1.890619      4
# 1  0.661994  1.261247 -1.626202  0.645470 -1.040277  1.180104      4
# 2  0.054573  0.704213 -1.259213  0.355717  2.854498  0.161426      2
# 3 -2.119641  1.931739  0.102478 -0.344210 -1.543026  0.219753      3
# 4 -0.253242  0.485880 -0.096521  1.707113  1.080979  0.001488      2
#
# [5 rows x 101 columns]

# %% [markdown]
# <b>2)</b> Looking at the data, which classifier would be best?

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, f1_score

# %% [markdown]
# <b>3)</b> Fit a KNN, SVM, and Random Forest model to the training data. Record how long it takes to train each model.

# %%
import time

start = time.time()
knn = KNeighborsClassifier(n_neighbors=65).fit(X_train,y_train)
y_pred = knn.predict(X_test)
from sklearn.metrics import accuracy_score
print('KNN')
print('Acc:', accuracy_score(y_test, y_pred))
print('F1:', f1_score(y_test, y_pred, average = None))
print('Time:', np.round(time.time()-start,2), 'seconds')

start = time.time()
svm = SVC(kernel='rbf', random_state=4).fit(X_train, y_train)
y_pred = svm.predict(X_test)
print('RBF Kernel')
print('Acc:', accuracy_score(y_test, y_pred))
print('F1:', f1_score(y_test, y_pred, average = None))
print('Time:', np.round(time.time()-start,2), 'seconds')

start = time.time()
rf_clf = RandomForestClassifier(random_state=4).fit(X_train, y_train)
y_pred = rf_clf.predict(X_test)
print('Acc:', accuracy_score(y_test, y_pred))
print('F1:', f1_score(y_test, y_pred, labels = y_train.unique(), average = None))
print('Time:', np.round(time.time()-start,2), 'seconds')

## ... train ...
# Out:
# KNN
# Acc: 0.5113333333333333
# F1: [0.57918552 0.51828299 0.61129568 0.43361345 0.38747554]
# Time: 3.21 seconds
# RBF Kernel
# Acc: 0.6153333333333333
# F1: [0.71949287 0.62865948 0.70989761 0.47348485 0.52475248]
# Time: 12.63 seconds
# Acc: 0.6566666666666666
# F1: [0.75917065 0.73701843 0.55258467 0.66865672 0.54311927]
# Time: 8.13 seconds

# %% [markdown]
# <b>4)</b> Make predictions using each model on the test data. Record the accuracy and F1 score of each. Which model performs best?

# %% [markdown]
# <b>5)</b> Choose one of the models and perform a grid-search to choose the best hyperparameters.

# %%
## https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html
from sklearn.model_selection import GridSearchCV
params = {}

from sklearn.model_selection import GridSearchCV
params = {'class_weight': ['balanced'], 'criterion': ['gini'],
         'max_depth': [6], 'max_features': ['auto']}
grid_search_model = GridSearchCV(rf_clf, params, cv =5)
x = grid_search_model.fit(X_train, y_train)
y_pred = x.predict(X_test)
print('Acc:', accuracy_score(y_test, y_pred))
print('F1:', f1_score(y_test, y_pred, average = None))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-1cd44514e9ac> in <module>()
#       8 grid_search_model = GridSearchCV(rf_clf, params, cv =5)
#       9 x = grid_search_model.fit(X_train, y_train)
# ---> 10 grid_search_model.best_params
#      11 y_pred = x.predict(X_test)
#      12 print('Acc:', accuracy_score(y_test, y_pred))
#
# AttributeError: 'GridSearchCV' object has no attribute 'best_params'
