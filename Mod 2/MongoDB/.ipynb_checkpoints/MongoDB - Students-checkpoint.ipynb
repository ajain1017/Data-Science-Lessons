# %% [markdown]
# # <center> Pokemon-goDB

# %% [markdown]
# <img src='mongo.jpeg'>

# %% [markdown]
# Start by running `mongod` in your terminal.

# %% [markdown]
# Import libraries.

# %%
import sqlite3 
import pandas as pd
import requests
import json
import pymongo

# %% [markdown]
# Connect to Mongo, create a database and a collection.

# %%
client = pymongo.MongoClient("mongodb://127.0.0.1:27017/")
poke_db = client['pokemon_db']
poke_collection = poke_db['pokemon_collection']

# %% [markdown]
# Create an entry and insert it into the collection.

# %%
pikachu = {'name': 'Pikachu', 'primary_type': 'Electric', 'secondary_type': 'None', 'level':25}
results = poke_collection.insert_one(pikachu)

# %% [markdown]
# Run a query to find all items in the collection.

# %%
q = poke_collection.find({})
for i in q:
    print(i)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# Insert multiple entries at once.

# %%
charmander = {'name': 'Charmander', 'primary_type': 'Fire', 'secondary_type': 'None', 'level':12}
bulbasaur = {'name': 'Bulbasaur',  'primary_type': 'Grass', 'secondary_type': 'Poison', 'level':10}
squirtle = {'name': 'Squirtle',  'primary_type': 'Water', 'secondary_type': 'None', 'level':8}

starters_list = [charmander, bulbasaur, squirtle]

results = poke_collection.insert_many(starters_list)

# %% [markdown]
# Query just the names of all the entered Pokemon without the IDs.

# %%
q = poke_collection.find({}, {'name':1, '_id':0})
for i in q:
    print(i)
# Out:
# {'name': 'bulbasaur'}
# {'name': 'ivysaur'}
# {'name': 'venusaur'}
# {'name': 'charmander'}
# {'name': 'charmeleon'}
# {'name': 'charizard'}
# {'name': 'squirtle'}
# {'name': 'wartortle'}
# {'name': 'blastoise'}
# {'name': 'bulbasaur'}
# {'name': 'ivysaur'}
# {'name': 'venusaur'}
# {'name': 'charmander'}
# {'name': 'charmeleon'}
# {'name': 'charizard'}
# {'name': 'squirtle'}
# {'name': 'wartortle'}
# {'name': 'blastoise'}
# {'name': 'bulbasaur'}
# {'name': 'ivysaur'}
# {'name': 'venusaur'}
# {'name': 'charmander'}
# {'name': 'charmeleon'}
# {'name': 'charizard'}
# {'name': 'squirtle'}
# {'name': 'wartortle'}
# {'name': 'blastoise'}
# {'name': 'caterpie'}
# {'name': 'metapod'}
# {'name': 'butterfree'}
# {'name': 'weedle'}
# {'name': 'kakuna'}
# {'name': 'beedrill'}
# {'name': 'pidgey'}
# {'name': 'pidgeotto'}
# {'name': 'pidgeot'}
# {'name': 'rattata'}
# {'name': 'raticate'}
# {'name': 'spearow'}
# {'name': 'fearow'}
# {'name': 'ekans'}
# {'name': 'arbok'}
# {'name': 'pikachu'}
# {'name': 'raichu'}
# {'name': 'sandshrew'}
# {'name': 'sandslash'}
# {'name': 'nidoran-f'}
# {'name': 'nidorina'}
# {'name': 'nidoqueen'}
# {'name': 'nidoran-m'}
# {'name': 'nidorino'}
# {'name': 'nidoking'}
# {'name': 'clefairy'}
# {'name': 'clefable'}
# {'name': 'vulpix'}
# {'name': 'ninetales'}
# {'name': 'jigglypuff'}
# {'name': 'wigglytuff'}
# {'name': 'zubat'}
# {'name': 'golbat'}
# {'name': 'oddish'}
# {'name': 'gloom'}
# {'name': 'vileplume'}
# {'name': 'paras'}
# {'name': 'parasect'}
# {'name': 'venonat'}
# {'name': 'venomoth'}
# {'name': 'diglett'}
# {'name': 'dugtrio'}
# {'name': 'meowth'}
# {'name': 'persian'}
# {'name': 'psyduck'}
# {'name': 'golduck'}
# {'name': 'mankey'}
# {'name': 'primeape'}
# {'name': 'growlithe'}
# {'name': 'arcanine'}
# {'name': 'poliwag'}
# {'name': 'poliwhirl'}
# {'name': 'poliwrath'}
# {'name': 'abra'}
# {'name': 'kadabra'}
# {'name': 'alakazam'}
# {'name': 'machop'}
# {'name': 'machoke'}
# {'name': 'machamp'}
# {'name': 'bellsprout'}
# {'name': 'weepinbell'}
# {'name': 'victreebel'}
# {'name': 'tentacool'}
# {'name': 'tentacruel'}
# {'name': 'geodude'}
# {'name': 'graveler'}
# {'name': 'golem'}
# {'name': 'ponyta'}
# {'name': 'rapidash'}
# {'name': 'slowpoke'}
# {'name': 'slowbro'}
# {'name': 'magnemite'}
# {'name': 'magneton'}
# {'name': 'farfetchd'}
# {'name': 'doduo'}
# {'name': 'dodrio'}
# {'name': 'seel'}
# {'name': 'dewgong'}
# {'name': 'grimer'}
# {'name': 'muk'}
# {'name': 'shellder'}
# {'name': 'cloyster'}
# {'name': 'gastly'}
# {'name': 'haunter'}
# {'name': 'gengar'}
# {'name': 'onix'}
# {'name': 'drowzee'}
# {'name': 'hypno'}
# {'name': 'krabby'}
# {'name': 'kingler'}
# {'name': 'voltorb'}
# {'name': 'electrode'}
# {'name': 'exeggcute'}
# {'name': 'exeggutor'}
# {'name': 'cubone'}
# {'name': 'marowak'}
# {'name': 'hitmonlee'}
# {'name': 'hitmonchan'}
# {'name': 'lickitung'}
# {'name': 'koffing'}
# {'name': 'weezing'}
# {'name': 'rhyhorn'}
# {'name': 'rhydon'}
# {'name': 'chansey'}
# {'name': 'tangela'}
# {'name': 'kangaskhan'}
# {'name': 'horsea'}
# {'name': 'seadra'}
# {'name': 'goldeen'}
# {'name': 'seaking'}
# {'name': 'staryu'}
# {'name': 'starmie'}
# {'name': 'mr-mime'}
# {'name': 'scyther'}
# {'name': 'jynx'}
# {'name': 'electabuzz'}
# {'name': 'magmar'}
# {'name': 'pinsir'}
# {'name': 'tauros'}
# {'name': 'magikarp'}
# {'name': 'gyarados'}
# {'name': 'lapras'}
# {'name': 'ditto'}
# {'name': 'eevee'}
# {'name': 'vaporeon'}
# {'name': 'jolteon'}
# {'name': 'flareon'}
# {'name': 'porygon'}
# {'name': 'omanyte'}
# {'name': 'omastar'}
# {'name': 'kabuto'}
# {'name': 'kabutops'}
# {'name': 'aerodactyl'}
# {'name': 'snorlax'}
# {'name': 'articuno'}
# {'name': 'zapdos'}
# {'name': 'moltres'}
# {'name': 'dratini'}
# {'name': 'dragonair'}
# {'name': 'dragonite'}
# {'name': 'mewtwo'}
# {'name': 'mew'}
# {'name': 'bulbasaur'}
# {'name': 'ivysaur'}
# {'name': 'venusaur'}
# {'name': 'charmander'}
# {'name': 'charmeleon'}
# {'name': 'charizard'}
# {'name': 'squirtle'}
# {'name': 'wartortle'}
# {'name': 'blastoise'}
# {'name': 'caterpie'}
# {'name': 'metapod'}
# {'name': 'butterfree'}
# {'name': 'weedle'}
# {'name': 'kakuna'}
# {'name': 'beedrill'}
# {'name': 'pidgey'}
# {'name': 'pidgeotto'}
# {'name': 'pidgeot'}
# {'name': 'rattata'}
# {'name': 'raticate'}
# {'name': 'spearow'}
# {'name': 'fearow'}
# {'name': 'ekans'}
# {'name': 'arbok'}
# {'name': 'pikachu'}
# {'name': 'raichu'}
# {'name': 'sandshrew'}
# {'name': 'sandslash'}
# {'name': 'nidoran-f'}
# {'name': 'nidorina'}
# {'name': 'nidoqueen'}
# {'name': 'nidoran-m'}
# {'name': 'nidorino'}
# {'name': 'nidoking'}
# {'name': 'clefairy'}
# {'name': 'clefable'}
# {'name': 'vulpix'}
# {'name': 'ninetales'}
# {'name': 'jigglypuff'}
# {'name': 'wigglytuff'}
# {'name': 'zubat'}
# {'name': 'golbat'}
# {'name': 'oddish'}
# {'name': 'gloom'}
# {'name': 'vileplume'}
# {'name': 'paras'}
# {'name': 'parasect'}
# {'name': 'venonat'}
# {'name': 'venomoth'}
# {'name': 'diglett'}
# {'name': 'dugtrio'}
# {'name': 'meowth'}
# {'name': 'persian'}
# {'name': 'psyduck'}
# {'name': 'golduck'}
# {'name': 'mankey'}
# {'name': 'primeape'}
# {'name': 'growlithe'}
# {'name': 'arcanine'}
# {'name': 'poliwag'}
# {'name': 'poliwhirl'}
# {'name': 'poliwrath'}
# {'name': 'abra'}
# {'name': 'kadabra'}
# {'name': 'alakazam'}
# {'name': 'machop'}
# {'name': 'machoke'}
# {'name': 'machamp'}
# {'name': 'bellsprout'}
# {'name': 'weepinbell'}
# {'name': 'victreebel'}
# {'name': 'tentacool'}
# {'name': 'tentacruel'}
# {'name': 'geodude'}
# {'name': 'graveler'}
# {'name': 'golem'}
# {'name': 'ponyta'}
# {'name': 'rapidash'}
# {'name': 'slowpoke'}
# {'name': 'slowbro'}
# {'name': 'magnemite'}
# {'name': 'magneton'}
# {'name': 'farfetchd'}
# {'name': 'doduo'}
# {'name': 'dodrio'}
# {'name': 'seel'}
# {'name': 'dewgong'}
# {'name': 'grimer'}
# {'name': 'muk'}
# {'name': 'shellder'}
# {'name': 'cloyster'}
# {'name': 'gastly'}
# {'name': 'haunter'}
# {'name': 'gengar'}
# {'name': 'onix'}
# {'name': 'drowzee'}
# {'name': 'hypno'}
# {'name': 'krabby'}
# {'name': 'kingler'}
# {'name': 'voltorb'}
# {'name': 'electrode'}
# {'name': 'exeggcute'}
# {'name': 'exeggutor'}
# {'name': 'cubone'}
# {'name': 'marowak'}
# {'name': 'hitmonlee'}
# {'name': 'hitmonchan'}
# {'name': 'lickitung'}
# {'name': 'koffing'}
# {'name': 'weezing'}
# {'name': 'rhyhorn'}
# {'name': 'rhydon'}
# {'name': 'chansey'}
# {'name': 'tangela'}
# {'name': 'kangaskhan'}
# {'name': 'horsea'}
# {'name': 'seadra'}
# {'name': 'goldeen'}
# {'name': 'seaking'}
# {'name': 'staryu'}
# {'name': 'starmie'}
# {'name': 'mr-mime'}
# {'name': 'scyther'}
# {'name': 'jynx'}
# {'name': 'electabuzz'}
# {'name': 'magmar'}
# {'name': 'pinsir'}
# {'name': 'tauros'}
# {'name': 'magikarp'}
# {'name': 'gyarados'}
# {'name': 'lapras'}
# {'name': 'ditto'}
# {'name': 'eevee'}
# {'name': 'vaporeon'}
# {'name': 'jolteon'}
# {'name': 'flareon'}
# {'name': 'porygon'}
# {'name': 'omanyte'}
# {'name': 'omastar'}
# {'name': 'kabuto'}
# {'name': 'kabutops'}
# {'name': 'aerodactyl'}
# {'name': 'snorlax'}
# {'name': 'articuno'}
# {'name': 'zapdos'}
# {'name': 'moltres'}
# {'name': 'dratini'}
# {'name': 'dragonair'}
# {'name': 'dragonite'}
# {'name': 'mewtwo'}
# {'name': 'mew'}
# {'name': 'bulbasaur'}
# {'name': 'ivysaur'}
# {'name': 'venusaur'}
# {'name': 'charmander'}
# {'name': 'charmeleon'}
# {'name': 'charizard'}
# {'name': 'squirtle'}
# {'name': 'wartortle'}
# {'name': 'blastoise'}
# {'name': 'caterpie'}
# {'name': 'metapod'}
# {'name': 'butterfree'}
# {'name': 'weedle'}
# {'name': 'kakuna'}
# {'name': 'beedrill'}
# {'name': 'pidgey'}
# {'name': 'pidgeotto'}
# {'name': 'pidgeot'}
# {'name': 'rattata'}
# {'name': 'raticate'}
# {'name': 'spearow'}
# {'name': 'fearow'}
# {'name': 'ekans'}
# {'name': 'arbok'}
# {'name': 'pikachu'}
# {'name': 'raichu'}
# {'name': 'sandshrew'}
# {'name': 'sandslash'}
# {'name': 'nidoran-f'}
# {'name': 'nidorina'}
# {'name': 'nidoqueen'}
# {'name': 'nidoran-m'}
# {'name': 'nidorino'}
# {'name': 'nidoking'}
# {'name': 'clefairy'}
# {'name': 'clefable'}
# {'name': 'vulpix'}
# {'name': 'ninetales'}
# {'name': 'jigglypuff'}
# {'name': 'wigglytuff'}
# {'name': 'zubat'}
# {'name': 'golbat'}
# {'name': 'oddish'}
# {'name': 'gloom'}
# {'name': 'vileplume'}
# {'name': 'paras'}
# {'name': 'parasect'}
# {'name': 'venonat'}
# {'name': 'venomoth'}
# {'name': 'diglett'}
# {'name': 'dugtrio'}
# {'name': 'meowth'}
# {'name': 'persian'}
# {'name': 'psyduck'}
# {'name': 'golduck'}
# {'name': 'mankey'}
# {'name': 'primeape'}
# {'name': 'growlithe'}
# {'name': 'arcanine'}
# {'name': 'poliwag'}
# {'name': 'poliwhirl'}
# {'name': 'poliwrath'}
# {'name': 'abra'}
# {'name': 'kadabra'}
# {'name': 'alakazam'}
# {'name': 'machop'}
# {'name': 'machoke'}
# {'name': 'machamp'}
# {'name': 'bellsprout'}
# {'name': 'weepinbell'}
# {'name': 'victreebel'}
# {'name': 'tentacool'}
# {'name': 'tentacruel'}
# {'name': 'geodude'}
# {'name': 'graveler'}
# {'name': 'golem'}
# {'name': 'ponyta'}
# {'name': 'rapidash'}
# {'name': 'slowpoke'}
# {'name': 'slowbro'}
# {'name': 'magnemite'}
# {'name': 'magneton'}
# {'name': 'farfetchd'}
# {'name': 'doduo'}
# {'name': 'dodrio'}
# {'name': 'seel'}
# {'name': 'dewgong'}
# {'name': 'grimer'}
# {'name': 'muk'}
# {'name': 'shellder'}
# {'name': 'cloyster'}
# {'name': 'gastly'}
# {'name': 'haunter'}
# {'name': 'gengar'}
# {'name': 'onix'}
# {'name': 'drowzee'}
# {'name': 'hypno'}
# {'name': 'krabby'}
# {'name': 'kingler'}
# {'name': 'voltorb'}
# {'name': 'electrode'}
# {'name': 'exeggcute'}
# {'name': 'exeggutor'}
# {'name': 'cubone'}
# {'name': 'marowak'}
# {'name': 'hitmonlee'}
# {'name': 'hitmonchan'}
# {'name': 'lickitung'}
# {'name': 'koffing'}
# {'name': 'weezing'}
# {'name': 'rhyhorn'}
# {'name': 'rhydon'}
# {'name': 'chansey'}
# {'name': 'tangela'}
# {'name': 'kangaskhan'}
# {'name': 'horsea'}
# {'name': 'seadra'}
# {'name': 'goldeen'}
# {'name': 'seaking'}
# {'name': 'staryu'}
# {'name': 'starmie'}
# {'name': 'mr-mime'}
# {'name': 'scyther'}
# {'name': 'jynx'}
# {'name': 'electabuzz'}
# {'name': 'magmar'}
# {'name': 'pinsir'}
# {'name': 'tauros'}
# {'name': 'magikarp'}
# {'name': 'gyarados'}
# {'name': 'lapras'}
# {'name': 'ditto'}
# {'name': 'eevee'}
# {'name': 'vaporeon'}
# {'name': 'jolteon'}
# {'name': 'flareon'}
# {'name': 'porygon'}
# {'name': 'omanyte'}
# {'name': 'omastar'}
# {'name': 'kabuto'}
# {'name': 'kabutops'}
# {'name': 'aerodactyl'}
# {'name': 'snorlax'}
# {'name': 'articuno'}
# {'name': 'zapdos'}
# {'name': 'moltres'}
# {'name': 'dratini'}
# {'name': 'dragonair'}
# {'name': 'dragonite'}
# {'name': 'mewtwo'}
# {'name': 'mew'}
# {'name': 'bulbasaur'}
# {'name': 'ivysaur'}
# {'name': 'venusaur'}
# {'name': 'charmander'}
# {'name': 'charmeleon'}
# {'name': 'charizard'}
# {'name': 'squirtle'}
# {'name': 'wartortle'}
# {'name': 'blastoise'}
# {'name': 'caterpie'}
# {'name': 'metapod'}
# {'name': 'butterfree'}
# {'name': 'weedle'}
# {'name': 'kakuna'}
# {'name': 'beedrill'}
# {'name': 'pidgey'}
# {'name': 'pidgeotto'}
# {'name': 'pidgeot'}
# {'name': 'rattata'}
# {'name': 'raticate'}
# {'name': 'spearow'}
# {'name': 'fearow'}
# {'name': 'ekans'}
# {'name': 'arbok'}
# {'name': 'pikachu'}
# {'name': 'raichu'}
# {'name': 'sandshrew'}
# {'name': 'sandslash'}
# {'name': 'nidoran-f'}
# {'name': 'nidorina'}
# {'name': 'nidoqueen'}
# {'name': 'nidoran-m'}
# {'name': 'nidorino'}
# {'name': 'nidoking'}
# {'name': 'clefairy'}
# {'name': 'clefable'}
# {'name': 'vulpix'}
# {'name': 'ninetales'}
# {'name': 'jigglypuff'}
# {'name': 'wigglytuff'}
# {'name': 'zubat'}
# {'name': 'golbat'}
# {'name': 'oddish'}
# {'name': 'gloom'}
# {'name': 'vileplume'}
# {'name': 'paras'}
# {'name': 'parasect'}
# {'name': 'venonat'}
# {'name': 'venomoth'}
# {'name': 'diglett'}
# {'name': 'dugtrio'}
# {'name': 'meowth'}
# {'name': 'persian'}
# {'name': 'psyduck'}
# {'name': 'golduck'}
# {'name': 'mankey'}
# {'name': 'primeape'}
# {'name': 'growlithe'}
# {'name': 'arcanine'}
# {'name': 'poliwag'}
# {'name': 'poliwhirl'}
# {'name': 'poliwrath'}
# {'name': 'abra'}
# {'name': 'kadabra'}
# {'name': 'alakazam'}
# {'name': 'machop'}
# {'name': 'machoke'}
# {'name': 'machamp'}
# {'name': 'bellsprout'}
# {'name': 'weepinbell'}
# {'name': 'victreebel'}
# {'name': 'tentacool'}
# {'name': 'tentacruel'}
# {'name': 'geodude'}
# {'name': 'graveler'}
# {'name': 'golem'}
# {'name': 'ponyta'}
# {'name': 'rapidash'}
# {'name': 'slowpoke'}
# {'name': 'slowbro'}
# {'name': 'magnemite'}
# {'name': 'magneton'}
# {'name': 'farfetchd'}
# {'name': 'doduo'}
# {'name': 'dodrio'}
# {'name': 'seel'}
# {'name': 'dewgong'}
# {'name': 'grimer'}
# {'name': 'muk'}
# {'name': 'shellder'}
# {'name': 'cloyster'}
# {'name': 'gastly'}
# {'name': 'haunter'}
# {'name': 'gengar'}
# {'name': 'onix'}
# {'name': 'drowzee'}
# {'name': 'hypno'}
# {'name': 'krabby'}
# {'name': 'kingler'}
# {'name': 'voltorb'}
# {'name': 'electrode'}
# {'name': 'exeggcute'}
# {'name': 'exeggutor'}
# {'name': 'cubone'}
# {'name': 'marowak'}
# {'name': 'hitmonlee'}
# {'name': 'hitmonchan'}
# {'name': 'lickitung'}
# {'name': 'koffing'}
# {'name': 'weezing'}
# {'name': 'rhyhorn'}
# {'name': 'rhydon'}
# {'name': 'chansey'}
# {'name': 'tangela'}
# {'name': 'kangaskhan'}
# {'name': 'horsea'}
# {'name': 'seadra'}
# {'name': 'goldeen'}
# {'name': 'seaking'}
# {'name': 'staryu'}
# {'name': 'starmie'}
# {'name': 'mr-mime'}
# {'name': 'scyther'}
# {'name': 'jynx'}
# {'name': 'electabuzz'}
# {'name': 'magmar'}
# {'name': 'pinsir'}
# {'name': 'tauros'}
# {'name': 'magikarp'}
# {'name': 'gyarados'}
# {'name': 'lapras'}
# {'name': 'ditto'}
# {'name': 'eevee'}
# {'name': 'vaporeon'}
# {'name': 'jolteon'}
# {'name': 'flareon'}
# {'name': 'porygon'}
# {'name': 'omanyte'}
# {'name': 'omastar'}
# {'name': 'kabuto'}
# {'name': 'kabutops'}
# {'name': 'aerodactyl'}
# {'name': 'snorlax'}
# {'name': 'articuno'}
# {'name': 'zapdos'}
# {'name': 'moltres'}
# {'name': 'dratini'}
# {'name': 'dragonair'}
# {'name': 'dragonite'}
# {'name': 'mewtwo'}
# {'name': 'mew'}
# {'name': 'bulbasaur'}
# {'name': 'ivysaur'}
# {'name': 'venusaur'}
# {'name': 'charmander'}
# {'name': 'charmeleon'}
# {'name': 'charizard'}
# {'name': 'squirtle'}
# {'name': 'wartortle'}
# {'name': 'blastoise'}
# {'name': 'caterpie'}
# {'name': 'metapod'}
# {'name': 'butterfree'}
# {'name': 'weedle'}
# {'name': 'kakuna'}
# {'name': 'beedrill'}
# {'name': 'pidgey'}
# {'name': 'pidgeotto'}
# {'name': 'pidgeot'}
# {'name': 'rattata'}
# {'name': 'raticate'}
# {'name': 'spearow'}
# {'name': 'fearow'}
# {'name': 'ekans'}
# {'name': 'arbok'}
# {'name': 'pikachu'}
# {'name': 'raichu'}
# {'name': 'sandshrew'}
# {'name': 'sandslash'}
# {'name': 'nidoran-f'}
# {'name': 'nidorina'}
# {'name': 'nidoqueen'}
# {'name': 'nidoran-m'}
# {'name': 'nidorino'}
# {'name': 'nidoking'}
# {'name': 'clefairy'}
# {'name': 'clefable'}
# {'name': 'vulpix'}
# {'name': 'ninetales'}
# {'name': 'jigglypuff'}
# {'name': 'wigglytuff'}
# {'name': 'zubat'}
# {'name': 'golbat'}
# {'name': 'oddish'}
# {'name': 'gloom'}
# {'name': 'vileplume'}
# {'name': 'paras'}
# {'name': 'parasect'}
# {'name': 'venonat'}
# {'name': 'venomoth'}
# {'name': 'diglett'}
# {'name': 'dugtrio'}
# {'name': 'meowth'}
# {'name': 'persian'}
# {'name': 'psyduck'}
# {'name': 'golduck'}
# {'name': 'mankey'}
# {'name': 'primeape'}
# {'name': 'growlithe'}
# {'name': 'arcanine'}
# {'name': 'poliwag'}
# {'name': 'poliwhirl'}
# {'name': 'poliwrath'}
# {'name': 'abra'}
# {'name': 'kadabra'}
# {'name': 'alakazam'}
# {'name': 'machop'}
# {'name': 'machoke'}
# {'name': 'machamp'}
# {'name': 'bellsprout'}
# {'name': 'weepinbell'}
# {'name': 'victreebel'}
# {'name': 'tentacool'}
# {'name': 'tentacruel'}
# {'name': 'geodude'}
# {'name': 'graveler'}
# {'name': 'golem'}
# {'name': 'ponyta'}
# {'name': 'rapidash'}
# {'name': 'slowpoke'}
# {'name': 'slowbro'}
# {'name': 'magnemite'}
# {'name': 'magneton'}
# {'name': 'farfetchd'}
# {'name': 'doduo'}
# {'name': 'dodrio'}
# {'name': 'seel'}
# {'name': 'dewgong'}
# {'name': 'grimer'}
# {'name': 'muk'}
# {'name': 'shellder'}
# {'name': 'cloyster'}
# {'name': 'gastly'}
# {'name': 'haunter'}
# {'name': 'gengar'}
# {'name': 'onix'}
# {'name': 'drowzee'}
# {'name': 'hypno'}
# {'name': 'krabby'}
# {'name': 'kingler'}
# {'name': 'voltorb'}
# {'name': 'electrode'}
# {'name': 'exeggcute'}
# {'name': 'exeggutor'}
# {'name': 'cubone'}
# {'name': 'marowak'}
# {'name': 'hitmonlee'}
# {'name': 'hitmonchan'}
# {'name': 'lickitung'}
# {'name': 'koffing'}
# {'name': 'weezing'}
# {'name': 'rhyhorn'}
# {'name': 'rhydon'}
# {'name': 'chansey'}
# {'name': 'tangela'}
# {'name': 'kangaskhan'}
# {'name': 'horsea'}
# {'name': 'seadra'}
# {'name': 'goldeen'}
# {'name': 'seaking'}
# {'name': 'staryu'}
# {'name': 'starmie'}
# {'name': 'mr-mime'}
# {'name': 'scyther'}
# {'name': 'jynx'}
# {'name': 'electabuzz'}
# {'name': 'magmar'}
# {'name': 'pinsir'}
# {'name': 'tauros'}
# {'name': 'magikarp'}
# {'name': 'gyarados'}
# {'name': 'lapras'}
# {'name': 'ditto'}
# {'name': 'eevee'}
# {'name': 'vaporeon'}
# {'name': 'jolteon'}
# {'name': 'flareon'}
# {'name': 'porygon'}
# {'name': 'omanyte'}
# {'name': 'omastar'}
# {'name': 'kabuto'}
# {'name': 'kabutops'}
# {'name': 'aerodactyl'}
# {'name': 'snorlax'}
# {'name': 'articuno'}
# {'name': 'zapdos'}
# {'name': 'moltres'}
# {'name': 'dratini'}
# {'name': 'dragonair'}
# {'name': 'dragonite'}
# {'name': 'mewtwo'}
# {'name': 'mew'}
# {'name': 'bulbasaur'}
# {'name': 'ivysaur'}
# {'name': 'venusaur'}
# {'name': 'charmander'}
# {'name': 'charmeleon'}
# {'name': 'charizard'}
# {'name': 'squirtle'}
# {'name': 'wartortle'}
# {'name': 'blastoise'}
# {'name': 'caterpie'}
# {'name': 'metapod'}
# {'name': 'butterfree'}
# {'name': 'weedle'}
# {'name': 'kakuna'}
# {'name': 'beedrill'}
# {'name': 'pidgey'}
# {'name': 'pidgeotto'}
# {'name': 'pidgeot'}
# {'name': 'rattata'}
# {'name': 'raticate'}
# {'name': 'spearow'}
# {'name': 'fearow'}
# {'name': 'ekans'}
# {'name': 'arbok'}
# {'name': 'pikachu'}
# {'name': 'raichu'}
# {'name': 'sandshrew'}
# {'name': 'sandslash'}
# {'name': 'nidoran-f'}
# {'name': 'nidorina'}
# {'name': 'nidoqueen'}
# {'name': 'nidoran-m'}
# {'name': 'nidorino'}
# {'name': 'nidoking'}
# {'name': 'clefairy'}
# {'name': 'clefable'}
# {'name': 'vulpix'}
# {'name': 'ninetales'}
# {'name': 'jigglypuff'}
# {'name': 'wigglytuff'}
# {'name': 'zubat'}
# {'name': 'golbat'}
# {'name': 'oddish'}
# {'name': 'gloom'}
# {'name': 'vileplume'}
# {'name': 'paras'}
# {'name': 'parasect'}
# {'name': 'venonat'}
# {'name': 'venomoth'}
# {'name': 'diglett'}
# {'name': 'dugtrio'}
# {'name': 'meowth'}
# {'name': 'persian'}
# {'name': 'psyduck'}
# {'name': 'golduck'}
# {'name': 'mankey'}
# {'name': 'primeape'}
# {'name': 'growlithe'}
# {'name': 'arcanine'}
# {'name': 'poliwag'}
# {'name': 'poliwhirl'}
# {'name': 'poliwrath'}
# {'name': 'abra'}
# {'name': 'kadabra'}
# {'name': 'alakazam'}
# {'name': 'machop'}
# {'name': 'machoke'}
# {'name': 'machamp'}
# {'name': 'bellsprout'}
# {'name': 'weepinbell'}
# {'name': 'victreebel'}
# {'name': 'tentacool'}
# {'name': 'tentacruel'}
# {'name': 'geodude'}
# {'name': 'graveler'}
# {'name': 'golem'}
# {'name': 'ponyta'}
# {'name': 'rapidash'}
# {'name': 'slowpoke'}
# {'name': 'slowbro'}
# {'name': 'magnemite'}
# {'name': 'magneton'}
# {'name': 'farfetchd'}
# {'name': 'doduo'}
# {'name': 'dodrio'}
# {'name': 'seel'}
# {'name': 'dewgong'}
# {'name': 'grimer'}
# {'name': 'muk'}
# {'name': 'shellder'}
# {'name': 'cloyster'}
# {'name': 'gastly'}
# {'name': 'haunter'}
# {'name': 'gengar'}
# {'name': 'onix'}
# {'name': 'drowzee'}
# {'name': 'hypno'}
# {'name': 'krabby'}
# {'name': 'kingler'}
# {'name': 'voltorb'}
# {'name': 'electrode'}
# {'name': 'exeggcute'}
# {'name': 'exeggutor'}
# {'name': 'cubone'}
# {'name': 'marowak'}
# {'name': 'hitmonlee'}
# {'name': 'hitmonchan'}
# {'name': 'lickitung'}
# {'name': 'koffing'}
# {'name': 'weezing'}
# {'name': 'rhyhorn'}
# {'name': 'rhydon'}
# {'name': 'chansey'}
# {'name': 'tangela'}
# {'name': 'kangaskhan'}
# {'name': 'horsea'}
# {'name': 'seadra'}
# {'name': 'goldeen'}
# {'name': 'seaking'}
# {'name': 'staryu'}
# {'name': 'starmie'}
# {'name': 'mr-mime'}
# {'name': 'scyther'}
# {'name': 'jynx'}
# {'name': 'electabuzz'}
# {'name': 'magmar'}
# {'name': 'pinsir'}
# {'name': 'tauros'}
# {'name': 'magikarp'}
# {'name': 'gyarados'}
# {'name': 'lapras'}
# {'name': 'ditto'}
# {'name': 'eevee'}
# {'name': 'vaporeon'}
# {'name': 'jolteon'}
# {'name': 'flareon'}
# {'name': 'porygon'}
# {'name': 'omanyte'}
# {'name': 'omastar'}
# {'name': 'kabuto'}
# {'name': 'kabutops'}
# {'name': 'aerodactyl'}
# {'name': 'snorlax'}
# {'name': 'articuno'}
# {'name': 'zapdos'}
# {'name': 'moltres'}
# {'name': 'dratini'}
# {'name': 'dragonair'}
# {'name': 'dragonite'}
# {'name': 'mewtwo'}
# {'name': 'mew'}
# {'name': 'Pikachu'}
# {'name': 'Charmander'}
# {'name': 'Bulbasaur'}
# {'name': 'Squirtle'}

# %% [markdown]
# Query the Pokemon with a level less than 20.

# %% [markdown]
# https://docs.mongodb.com/manual/reference/operator/query/#query-selectors

# %%
q = poke_collection.find({'level':{'$lt': 20}}, {'name':1, '_id':0})
for i in q:
    print(i)
# Out:
# {'name': 'Charmander'}
# {'name': 'Bulbasaur'}
# {'name': 'Squirtle'}

# %% [markdown]
# Delete an entry.

# %%
d = poke_collection.delete_one({'name': 'Pikachu'})
print(d.deleted_count)
# Out:
# 1

# %%
q = poke_collection.find({}, {'name':1, '_id':0})
for i in q:
    print(i)
# Out:
# {'name': 'bulbasaur'}
# {'name': 'ivysaur'}
# {'name': 'venusaur'}
# {'name': 'charmander'}
# {'name': 'charmeleon'}
# {'name': 'charizard'}
# {'name': 'squirtle'}
# {'name': 'wartortle'}
# {'name': 'blastoise'}
# {'name': 'bulbasaur'}
# {'name': 'ivysaur'}
# {'name': 'venusaur'}
# {'name': 'charmander'}
# {'name': 'charmeleon'}
# {'name': 'charizard'}
# {'name': 'squirtle'}
# {'name': 'wartortle'}
# {'name': 'blastoise'}
# {'name': 'bulbasaur'}
# {'name': 'ivysaur'}
# {'name': 'venusaur'}
# {'name': 'charmander'}
# {'name': 'charmeleon'}
# {'name': 'charizard'}
# {'name': 'squirtle'}
# {'name': 'wartortle'}
# {'name': 'blastoise'}
# {'name': 'caterpie'}
# {'name': 'metapod'}
# {'name': 'butterfree'}
# {'name': 'weedle'}
# {'name': 'kakuna'}
# {'name': 'beedrill'}
# {'name': 'pidgey'}
# {'name': 'pidgeotto'}
# {'name': 'pidgeot'}
# {'name': 'rattata'}
# {'name': 'raticate'}
# {'name': 'spearow'}
# {'name': 'fearow'}
# {'name': 'ekans'}
# {'name': 'arbok'}
# {'name': 'pikachu'}
# {'name': 'raichu'}
# {'name': 'sandshrew'}
# {'name': 'sandslash'}
# {'name': 'nidoran-f'}
# {'name': 'nidorina'}
# {'name': 'nidoqueen'}
# {'name': 'nidoran-m'}
# {'name': 'nidorino'}
# {'name': 'nidoking'}
# {'name': 'clefairy'}
# {'name': 'clefable'}
# {'name': 'vulpix'}
# {'name': 'ninetales'}
# {'name': 'jigglypuff'}
# {'name': 'wigglytuff'}
# {'name': 'zubat'}
# {'name': 'golbat'}
# {'name': 'oddish'}
# {'name': 'gloom'}
# {'name': 'vileplume'}
# {'name': 'paras'}
# {'name': 'parasect'}
# {'name': 'venonat'}
# {'name': 'venomoth'}
# {'name': 'diglett'}
# {'name': 'dugtrio'}
# {'name': 'meowth'}
# {'name': 'persian'}
# {'name': 'psyduck'}
# {'name': 'golduck'}
# {'name': 'mankey'}
# {'name': 'primeape'}
# {'name': 'growlithe'}
# {'name': 'arcanine'}
# {'name': 'poliwag'}
# {'name': 'poliwhirl'}
# {'name': 'poliwrath'}
# {'name': 'abra'}
# {'name': 'kadabra'}
# {'name': 'alakazam'}
# {'name': 'machop'}
# {'name': 'machoke'}
# {'name': 'machamp'}
# {'name': 'bellsprout'}
# {'name': 'weepinbell'}
# {'name': 'victreebel'}
# {'name': 'tentacool'}
# {'name': 'tentacruel'}
# {'name': 'geodude'}
# {'name': 'graveler'}
# {'name': 'golem'}
# {'name': 'ponyta'}
# {'name': 'rapidash'}
# {'name': 'slowpoke'}
# {'name': 'slowbro'}
# {'name': 'magnemite'}
# {'name': 'magneton'}
# {'name': 'farfetchd'}
# {'name': 'doduo'}
# {'name': 'dodrio'}
# {'name': 'seel'}
# {'name': 'dewgong'}
# {'name': 'grimer'}
# {'name': 'muk'}
# {'name': 'shellder'}
# {'name': 'cloyster'}
# {'name': 'gastly'}
# {'name': 'haunter'}
# {'name': 'gengar'}
# {'name': 'onix'}
# {'name': 'drowzee'}
# {'name': 'hypno'}
# {'name': 'krabby'}
# {'name': 'kingler'}
# {'name': 'voltorb'}
# {'name': 'electrode'}
# {'name': 'exeggcute'}
# {'name': 'exeggutor'}
# {'name': 'cubone'}
# {'name': 'marowak'}
# {'name': 'hitmonlee'}
# {'name': 'hitmonchan'}
# {'name': 'lickitung'}
# {'name': 'koffing'}
# {'name': 'weezing'}
# {'name': 'rhyhorn'}
# {'name': 'rhydon'}
# {'name': 'chansey'}
# {'name': 'tangela'}
# {'name': 'kangaskhan'}
# {'name': 'horsea'}
# {'name': 'seadra'}
# {'name': 'goldeen'}
# {'name': 'seaking'}
# {'name': 'staryu'}
# {'name': 'starmie'}
# {'name': 'mr-mime'}
# {'name': 'scyther'}
# {'name': 'jynx'}
# {'name': 'electabuzz'}
# {'name': 'magmar'}
# {'name': 'pinsir'}
# {'name': 'tauros'}
# {'name': 'magikarp'}
# {'name': 'gyarados'}
# {'name': 'lapras'}
# {'name': 'ditto'}
# {'name': 'eevee'}
# {'name': 'vaporeon'}
# {'name': 'jolteon'}
# {'name': 'flareon'}
# {'name': 'porygon'}
# {'name': 'omanyte'}
# {'name': 'omastar'}
# {'name': 'kabuto'}
# {'name': 'kabutops'}
# {'name': 'aerodactyl'}
# {'name': 'snorlax'}
# {'name': 'articuno'}
# {'name': 'zapdos'}
# {'name': 'moltres'}
# {'name': 'dratini'}
# {'name': 'dragonair'}
# {'name': 'dragonite'}
# {'name': 'mewtwo'}
# {'name': 'mew'}
# {'name': 'bulbasaur'}
# {'name': 'ivysaur'}
# {'name': 'venusaur'}
# {'name': 'charmander'}
# {'name': 'charmeleon'}
# {'name': 'charizard'}
# {'name': 'squirtle'}
# {'name': 'wartortle'}
# {'name': 'blastoise'}
# {'name': 'caterpie'}
# {'name': 'metapod'}
# {'name': 'butterfree'}
# {'name': 'weedle'}
# {'name': 'kakuna'}
# {'name': 'beedrill'}
# {'name': 'pidgey'}
# {'name': 'pidgeotto'}
# {'name': 'pidgeot'}
# {'name': 'rattata'}
# {'name': 'raticate'}
# {'name': 'spearow'}
# {'name': 'fearow'}
# {'name': 'ekans'}
# {'name': 'arbok'}
# {'name': 'pikachu'}
# {'name': 'raichu'}
# {'name': 'sandshrew'}
# {'name': 'sandslash'}
# {'name': 'nidoran-f'}
# {'name': 'nidorina'}
# {'name': 'nidoqueen'}
# {'name': 'nidoran-m'}
# {'name': 'nidorino'}
# {'name': 'nidoking'}
# {'name': 'clefairy'}
# {'name': 'clefable'}
# {'name': 'vulpix'}
# {'name': 'ninetales'}
# {'name': 'jigglypuff'}
# {'name': 'wigglytuff'}
# {'name': 'zubat'}
# {'name': 'golbat'}
# {'name': 'oddish'}
# {'name': 'gloom'}
# {'name': 'vileplume'}
# {'name': 'paras'}
# {'name': 'parasect'}
# {'name': 'venonat'}
# {'name': 'venomoth'}
# {'name': 'diglett'}
# {'name': 'dugtrio'}
# {'name': 'meowth'}
# {'name': 'persian'}
# {'name': 'psyduck'}
# {'name': 'golduck'}
# {'name': 'mankey'}
# {'name': 'primeape'}
# {'name': 'growlithe'}
# {'name': 'arcanine'}
# {'name': 'poliwag'}
# {'name': 'poliwhirl'}
# {'name': 'poliwrath'}
# {'name': 'abra'}
# {'name': 'kadabra'}
# {'name': 'alakazam'}
# {'name': 'machop'}
# {'name': 'machoke'}
# {'name': 'machamp'}
# {'name': 'bellsprout'}
# {'name': 'weepinbell'}
# {'name': 'victreebel'}
# {'name': 'tentacool'}
# {'name': 'tentacruel'}
# {'name': 'geodude'}
# {'name': 'graveler'}
# {'name': 'golem'}
# {'name': 'ponyta'}
# {'name': 'rapidash'}
# {'name': 'slowpoke'}
# {'name': 'slowbro'}
# {'name': 'magnemite'}
# {'name': 'magneton'}
# {'name': 'farfetchd'}
# {'name': 'doduo'}
# {'name': 'dodrio'}
# {'name': 'seel'}
# {'name': 'dewgong'}
# {'name': 'grimer'}
# {'name': 'muk'}
# {'name': 'shellder'}
# {'name': 'cloyster'}
# {'name': 'gastly'}
# {'name': 'haunter'}
# {'name': 'gengar'}
# {'name': 'onix'}
# {'name': 'drowzee'}
# {'name': 'hypno'}
# {'name': 'krabby'}
# {'name': 'kingler'}
# {'name': 'voltorb'}
# {'name': 'electrode'}
# {'name': 'exeggcute'}
# {'name': 'exeggutor'}
# {'name': 'cubone'}
# {'name': 'marowak'}
# {'name': 'hitmonlee'}
# {'name': 'hitmonchan'}
# {'name': 'lickitung'}
# {'name': 'koffing'}
# {'name': 'weezing'}
# {'name': 'rhyhorn'}
# {'name': 'rhydon'}
# {'name': 'chansey'}
# {'name': 'tangela'}
# {'name': 'kangaskhan'}
# {'name': 'horsea'}
# {'name': 'seadra'}
# {'name': 'goldeen'}
# {'name': 'seaking'}
# {'name': 'staryu'}
# {'name': 'starmie'}
# {'name': 'mr-mime'}
# {'name': 'scyther'}
# {'name': 'jynx'}
# {'name': 'electabuzz'}
# {'name': 'magmar'}
# {'name': 'pinsir'}
# {'name': 'tauros'}
# {'name': 'magikarp'}
# {'name': 'gyarados'}
# {'name': 'lapras'}
# {'name': 'ditto'}
# {'name': 'eevee'}
# {'name': 'vaporeon'}
# {'name': 'jolteon'}
# {'name': 'flareon'}
# {'name': 'porygon'}
# {'name': 'omanyte'}
# {'name': 'omastar'}
# {'name': 'kabuto'}
# {'name': 'kabutops'}
# {'name': 'aerodactyl'}
# {'name': 'snorlax'}
# {'name': 'articuno'}
# {'name': 'zapdos'}
# {'name': 'moltres'}
# {'name': 'dratini'}
# {'name': 'dragonair'}
# {'name': 'dragonite'}
# {'name': 'mewtwo'}
# {'name': 'mew'}
# {'name': 'bulbasaur'}
# {'name': 'ivysaur'}
# {'name': 'venusaur'}
# {'name': 'charmander'}
# {'name': 'charmeleon'}
# {'name': 'charizard'}
# {'name': 'squirtle'}
# {'name': 'wartortle'}
# {'name': 'blastoise'}
# {'name': 'caterpie'}
# {'name': 'metapod'}
# {'name': 'butterfree'}
# {'name': 'weedle'}
# {'name': 'kakuna'}
# {'name': 'beedrill'}
# {'name': 'pidgey'}
# {'name': 'pidgeotto'}
# {'name': 'pidgeot'}
# {'name': 'rattata'}
# {'name': 'raticate'}
# {'name': 'spearow'}
# {'name': 'fearow'}
# {'name': 'ekans'}
# {'name': 'arbok'}
# {'name': 'pikachu'}
# {'name': 'raichu'}
# {'name': 'sandshrew'}
# {'name': 'sandslash'}
# {'name': 'nidoran-f'}
# {'name': 'nidorina'}
# {'name': 'nidoqueen'}
# {'name': 'nidoran-m'}
# {'name': 'nidorino'}
# {'name': 'nidoking'}
# {'name': 'clefairy'}
# {'name': 'clefable'}
# {'name': 'vulpix'}
# {'name': 'ninetales'}
# {'name': 'jigglypuff'}
# {'name': 'wigglytuff'}
# {'name': 'zubat'}
# {'name': 'golbat'}
# {'name': 'oddish'}
# {'name': 'gloom'}
# {'name': 'vileplume'}
# {'name': 'paras'}
# {'name': 'parasect'}
# {'name': 'venonat'}
# {'name': 'venomoth'}
# {'name': 'diglett'}
# {'name': 'dugtrio'}
# {'name': 'meowth'}
# {'name': 'persian'}
# {'name': 'psyduck'}
# {'name': 'golduck'}
# {'name': 'mankey'}
# {'name': 'primeape'}
# {'name': 'growlithe'}
# {'name': 'arcanine'}
# {'name': 'poliwag'}
# {'name': 'poliwhirl'}
# {'name': 'poliwrath'}
# {'name': 'abra'}
# {'name': 'kadabra'}
# {'name': 'alakazam'}
# {'name': 'machop'}
# {'name': 'machoke'}
# {'name': 'machamp'}
# {'name': 'bellsprout'}
# {'name': 'weepinbell'}
# {'name': 'victreebel'}
# {'name': 'tentacool'}
# {'name': 'tentacruel'}
# {'name': 'geodude'}
# {'name': 'graveler'}
# {'name': 'golem'}
# {'name': 'ponyta'}
# {'name': 'rapidash'}
# {'name': 'slowpoke'}
# {'name': 'slowbro'}
# {'name': 'magnemite'}
# {'name': 'magneton'}
# {'name': 'farfetchd'}
# {'name': 'doduo'}
# {'name': 'dodrio'}
# {'name': 'seel'}
# {'name': 'dewgong'}
# {'name': 'grimer'}
# {'name': 'muk'}
# {'name': 'shellder'}
# {'name': 'cloyster'}
# {'name': 'gastly'}
# {'name': 'haunter'}
# {'name': 'gengar'}
# {'name': 'onix'}
# {'name': 'drowzee'}
# {'name': 'hypno'}
# {'name': 'krabby'}
# {'name': 'kingler'}
# {'name': 'voltorb'}
# {'name': 'electrode'}
# {'name': 'exeggcute'}
# {'name': 'exeggutor'}
# {'name': 'cubone'}
# {'name': 'marowak'}
# {'name': 'hitmonlee'}
# {'name': 'hitmonchan'}
# {'name': 'lickitung'}
# {'name': 'koffing'}
# {'name': 'weezing'}
# {'name': 'rhyhorn'}
# {'name': 'rhydon'}
# {'name': 'chansey'}
# {'name': 'tangela'}
# {'name': 'kangaskhan'}
# {'name': 'horsea'}
# {'name': 'seadra'}
# {'name': 'goldeen'}
# {'name': 'seaking'}
# {'name': 'staryu'}
# {'name': 'starmie'}
# {'name': 'mr-mime'}
# {'name': 'scyther'}
# {'name': 'jynx'}
# {'name': 'electabuzz'}
# {'name': 'magmar'}
# {'name': 'pinsir'}
# {'name': 'tauros'}
# {'name': 'magikarp'}
# {'name': 'gyarados'}
# {'name': 'lapras'}
# {'name': 'ditto'}
# {'name': 'eevee'}
# {'name': 'vaporeon'}
# {'name': 'jolteon'}
# {'name': 'flareon'}
# {'name': 'porygon'}
# {'name': 'omanyte'}
# {'name': 'omastar'}
# {'name': 'kabuto'}
# {'name': 'kabutops'}
# {'name': 'aerodactyl'}
# {'name': 'snorlax'}
# {'name': 'articuno'}
# {'name': 'zapdos'}
# {'name': 'moltres'}
# {'name': 'dratini'}
# {'name': 'dragonair'}
# {'name': 'dragonite'}
# {'name': 'mewtwo'}
# {'name': 'mew'}
# {'name': 'bulbasaur'}
# {'name': 'ivysaur'}
# {'name': 'venusaur'}
# {'name': 'charmander'}
# {'name': 'charmeleon'}
# {'name': 'charizard'}
# {'name': 'squirtle'}
# {'name': 'wartortle'}
# {'name': 'blastoise'}
# {'name': 'caterpie'}
# {'name': 'metapod'}
# {'name': 'butterfree'}
# {'name': 'weedle'}
# {'name': 'kakuna'}
# {'name': 'beedrill'}
# {'name': 'pidgey'}
# {'name': 'pidgeotto'}
# {'name': 'pidgeot'}
# {'name': 'rattata'}
# {'name': 'raticate'}
# {'name': 'spearow'}
# {'name': 'fearow'}
# {'name': 'ekans'}
# {'name': 'arbok'}
# {'name': 'pikachu'}
# {'name': 'raichu'}
# {'name': 'sandshrew'}
# {'name': 'sandslash'}
# {'name': 'nidoran-f'}
# {'name': 'nidorina'}
# {'name': 'nidoqueen'}
# {'name': 'nidoran-m'}
# {'name': 'nidorino'}
# {'name': 'nidoking'}
# {'name': 'clefairy'}
# {'name': 'clefable'}
# {'name': 'vulpix'}
# {'name': 'ninetales'}
# {'name': 'jigglypuff'}
# {'name': 'wigglytuff'}
# {'name': 'zubat'}
# {'name': 'golbat'}
# {'name': 'oddish'}
# {'name': 'gloom'}
# {'name': 'vileplume'}
# {'name': 'paras'}
# {'name': 'parasect'}
# {'name': 'venonat'}
# {'name': 'venomoth'}
# {'name': 'diglett'}
# {'name': 'dugtrio'}
# {'name': 'meowth'}
# {'name': 'persian'}
# {'name': 'psyduck'}
# {'name': 'golduck'}
# {'name': 'mankey'}
# {'name': 'primeape'}
# {'name': 'growlithe'}
# {'name': 'arcanine'}
# {'name': 'poliwag'}
# {'name': 'poliwhirl'}
# {'name': 'poliwrath'}
# {'name': 'abra'}
# {'name': 'kadabra'}
# {'name': 'alakazam'}
# {'name': 'machop'}
# {'name': 'machoke'}
# {'name': 'machamp'}
# {'name': 'bellsprout'}
# {'name': 'weepinbell'}
# {'name': 'victreebel'}
# {'name': 'tentacool'}
# {'name': 'tentacruel'}
# {'name': 'geodude'}
# {'name': 'graveler'}
# {'name': 'golem'}
# {'name': 'ponyta'}
# {'name': 'rapidash'}
# {'name': 'slowpoke'}
# {'name': 'slowbro'}
# {'name': 'magnemite'}
# {'name': 'magneton'}
# {'name': 'farfetchd'}
# {'name': 'doduo'}
# {'name': 'dodrio'}
# {'name': 'seel'}
# {'name': 'dewgong'}
# {'name': 'grimer'}
# {'name': 'muk'}
# {'name': 'shellder'}
# {'name': 'cloyster'}
# {'name': 'gastly'}
# {'name': 'haunter'}
# {'name': 'gengar'}
# {'name': 'onix'}
# {'name': 'drowzee'}
# {'name': 'hypno'}
# {'name': 'krabby'}
# {'name': 'kingler'}
# {'name': 'voltorb'}
# {'name': 'electrode'}
# {'name': 'exeggcute'}
# {'name': 'exeggutor'}
# {'name': 'cubone'}
# {'name': 'marowak'}
# {'name': 'hitmonlee'}
# {'name': 'hitmonchan'}
# {'name': 'lickitung'}
# {'name': 'koffing'}
# {'name': 'weezing'}
# {'name': 'rhyhorn'}
# {'name': 'rhydon'}
# {'name': 'chansey'}
# {'name': 'tangela'}
# {'name': 'kangaskhan'}
# {'name': 'horsea'}
# {'name': 'seadra'}
# {'name': 'goldeen'}
# {'name': 'seaking'}
# {'name': 'staryu'}
# {'name': 'starmie'}
# {'name': 'mr-mime'}
# {'name': 'scyther'}
# {'name': 'jynx'}
# {'name': 'electabuzz'}
# {'name': 'magmar'}
# {'name': 'pinsir'}
# {'name': 'tauros'}
# {'name': 'magikarp'}
# {'name': 'gyarados'}
# {'name': 'lapras'}
# {'name': 'ditto'}
# {'name': 'eevee'}
# {'name': 'vaporeon'}
# {'name': 'jolteon'}
# {'name': 'flareon'}
# {'name': 'porygon'}
# {'name': 'omanyte'}
# {'name': 'omastar'}
# {'name': 'kabuto'}
# {'name': 'kabutops'}
# {'name': 'aerodactyl'}
# {'name': 'snorlax'}
# {'name': 'articuno'}
# {'name': 'zapdos'}
# {'name': 'moltres'}
# {'name': 'dratini'}
# {'name': 'dragonair'}
# {'name': 'dragonite'}
# {'name': 'mewtwo'}
# {'name': 'mew'}
# {'name': 'bulbasaur'}
# {'name': 'ivysaur'}
# {'name': 'venusaur'}
# {'name': 'charmander'}
# {'name': 'charmeleon'}
# {'name': 'charizard'}
# {'name': 'squirtle'}
# {'name': 'wartortle'}
# {'name': 'blastoise'}
# {'name': 'caterpie'}
# {'name': 'metapod'}
# {'name': 'butterfree'}
# {'name': 'weedle'}
# {'name': 'kakuna'}
# {'name': 'beedrill'}
# {'name': 'pidgey'}
# {'name': 'pidgeotto'}
# {'name': 'pidgeot'}
# {'name': 'rattata'}
# {'name': 'raticate'}
# {'name': 'spearow'}
# {'name': 'fearow'}
# {'name': 'ekans'}
# {'name': 'arbok'}
# {'name': 'pikachu'}
# {'name': 'raichu'}
# {'name': 'sandshrew'}
# {'name': 'sandslash'}
# {'name': 'nidoran-f'}
# {'name': 'nidorina'}
# {'name': 'nidoqueen'}
# {'name': 'nidoran-m'}
# {'name': 'nidorino'}
# {'name': 'nidoking'}
# {'name': 'clefairy'}
# {'name': 'clefable'}
# {'name': 'vulpix'}
# {'name': 'ninetales'}
# {'name': 'jigglypuff'}
# {'name': 'wigglytuff'}
# {'name': 'zubat'}
# {'name': 'golbat'}
# {'name': 'oddish'}
# {'name': 'gloom'}
# {'name': 'vileplume'}
# {'name': 'paras'}
# {'name': 'parasect'}
# {'name': 'venonat'}
# {'name': 'venomoth'}
# {'name': 'diglett'}
# {'name': 'dugtrio'}
# {'name': 'meowth'}
# {'name': 'persian'}
# {'name': 'psyduck'}
# {'name': 'golduck'}
# {'name': 'mankey'}
# {'name': 'primeape'}
# {'name': 'growlithe'}
# {'name': 'arcanine'}
# {'name': 'poliwag'}
# {'name': 'poliwhirl'}
# {'name': 'poliwrath'}
# {'name': 'abra'}
# {'name': 'kadabra'}
# {'name': 'alakazam'}
# {'name': 'machop'}
# {'name': 'machoke'}
# {'name': 'machamp'}
# {'name': 'bellsprout'}
# {'name': 'weepinbell'}
# {'name': 'victreebel'}
# {'name': 'tentacool'}
# {'name': 'tentacruel'}
# {'name': 'geodude'}
# {'name': 'graveler'}
# {'name': 'golem'}
# {'name': 'ponyta'}
# {'name': 'rapidash'}
# {'name': 'slowpoke'}
# {'name': 'slowbro'}
# {'name': 'magnemite'}
# {'name': 'magneton'}
# {'name': 'farfetchd'}
# {'name': 'doduo'}
# {'name': 'dodrio'}
# {'name': 'seel'}
# {'name': 'dewgong'}
# {'name': 'grimer'}
# {'name': 'muk'}
# {'name': 'shellder'}
# {'name': 'cloyster'}
# {'name': 'gastly'}
# {'name': 'haunter'}
# {'name': 'gengar'}
# {'name': 'onix'}
# {'name': 'drowzee'}
# {'name': 'hypno'}
# {'name': 'krabby'}
# {'name': 'kingler'}
# {'name': 'voltorb'}
# {'name': 'electrode'}
# {'name': 'exeggcute'}
# {'name': 'exeggutor'}
# {'name': 'cubone'}
# {'name': 'marowak'}
# {'name': 'hitmonlee'}
# {'name': 'hitmonchan'}
# {'name': 'lickitung'}
# {'name': 'koffing'}
# {'name': 'weezing'}
# {'name': 'rhyhorn'}
# {'name': 'rhydon'}
# {'name': 'chansey'}
# {'name': 'tangela'}
# {'name': 'kangaskhan'}
# {'name': 'horsea'}
# {'name': 'seadra'}
# {'name': 'goldeen'}
# {'name': 'seaking'}
# {'name': 'staryu'}
# {'name': 'starmie'}
# {'name': 'mr-mime'}
# {'name': 'scyther'}
# {'name': 'jynx'}
# {'name': 'electabuzz'}
# {'name': 'magmar'}
# {'name': 'pinsir'}
# {'name': 'tauros'}
# {'name': 'magikarp'}
# {'name': 'gyarados'}
# {'name': 'lapras'}
# {'name': 'ditto'}
# {'name': 'eevee'}
# {'name': 'vaporeon'}
# {'name': 'jolteon'}
# {'name': 'flareon'}
# {'name': 'porygon'}
# {'name': 'omanyte'}
# {'name': 'omastar'}
# {'name': 'kabuto'}
# {'name': 'kabutops'}
# {'name': 'aerodactyl'}
# {'name': 'snorlax'}
# {'name': 'articuno'}
# {'name': 'zapdos'}
# {'name': 'moltres'}
# {'name': 'dratini'}
# {'name': 'dragonair'}
# {'name': 'dragonite'}
# {'name': 'mewtwo'}
# {'name': 'mew'}
# {'name': 'bulbasaur'}
# {'name': 'ivysaur'}
# {'name': 'venusaur'}
# {'name': 'charmander'}
# {'name': 'charmeleon'}
# {'name': 'charizard'}
# {'name': 'squirtle'}
# {'name': 'wartortle'}
# {'name': 'blastoise'}
# {'name': 'caterpie'}
# {'name': 'metapod'}
# {'name': 'butterfree'}
# {'name': 'weedle'}
# {'name': 'kakuna'}
# {'name': 'beedrill'}
# {'name': 'pidgey'}
# {'name': 'pidgeotto'}
# {'name': 'pidgeot'}
# {'name': 'rattata'}
# {'name': 'raticate'}
# {'name': 'spearow'}
# {'name': 'fearow'}
# {'name': 'ekans'}
# {'name': 'arbok'}
# {'name': 'pikachu'}
# {'name': 'raichu'}
# {'name': 'sandshrew'}
# {'name': 'sandslash'}
# {'name': 'nidoran-f'}
# {'name': 'nidorina'}
# {'name': 'nidoqueen'}
# {'name': 'nidoran-m'}
# {'name': 'nidorino'}
# {'name': 'nidoking'}
# {'name': 'clefairy'}
# {'name': 'clefable'}
# {'name': 'vulpix'}
# {'name': 'ninetales'}
# {'name': 'jigglypuff'}
# {'name': 'wigglytuff'}
# {'name': 'zubat'}
# {'name': 'golbat'}
# {'name': 'oddish'}
# {'name': 'gloom'}
# {'name': 'vileplume'}
# {'name': 'paras'}
# {'name': 'parasect'}
# {'name': 'venonat'}
# {'name': 'venomoth'}
# {'name': 'diglett'}
# {'name': 'dugtrio'}
# {'name': 'meowth'}
# {'name': 'persian'}
# {'name': 'psyduck'}
# {'name': 'golduck'}
# {'name': 'mankey'}
# {'name': 'primeape'}
# {'name': 'growlithe'}
# {'name': 'arcanine'}
# {'name': 'poliwag'}
# {'name': 'poliwhirl'}
# {'name': 'poliwrath'}
# {'name': 'abra'}
# {'name': 'kadabra'}
# {'name': 'alakazam'}
# {'name': 'machop'}
# {'name': 'machoke'}
# {'name': 'machamp'}
# {'name': 'bellsprout'}
# {'name': 'weepinbell'}
# {'name': 'victreebel'}
# {'name': 'tentacool'}
# {'name': 'tentacruel'}
# {'name': 'geodude'}
# {'name': 'graveler'}
# {'name': 'golem'}
# {'name': 'ponyta'}
# {'name': 'rapidash'}
# {'name': 'slowpoke'}
# {'name': 'slowbro'}
# {'name': 'magnemite'}
# {'name': 'magneton'}
# {'name': 'farfetchd'}
# {'name': 'doduo'}
# {'name': 'dodrio'}
# {'name': 'seel'}
# {'name': 'dewgong'}
# {'name': 'grimer'}
# {'name': 'muk'}
# {'name': 'shellder'}
# {'name': 'cloyster'}
# {'name': 'gastly'}
# {'name': 'haunter'}
# {'name': 'gengar'}
# {'name': 'onix'}
# {'name': 'drowzee'}
# {'name': 'hypno'}
# {'name': 'krabby'}
# {'name': 'kingler'}
# {'name': 'voltorb'}
# {'name': 'electrode'}
# {'name': 'exeggcute'}
# {'name': 'exeggutor'}
# {'name': 'cubone'}
# {'name': 'marowak'}
# {'name': 'hitmonlee'}
# {'name': 'hitmonchan'}
# {'name': 'lickitung'}
# {'name': 'koffing'}
# {'name': 'weezing'}
# {'name': 'rhyhorn'}
# {'name': 'rhydon'}
# {'name': 'chansey'}
# {'name': 'tangela'}
# {'name': 'kangaskhan'}
# {'name': 'horsea'}
# {'name': 'seadra'}
# {'name': 'goldeen'}
# {'name': 'seaking'}
# {'name': 'staryu'}
# {'name': 'starmie'}
# {'name': 'mr-mime'}
# {'name': 'scyther'}
# {'name': 'jynx'}
# {'name': 'electabuzz'}
# {'name': 'magmar'}
# {'name': 'pinsir'}
# {'name': 'tauros'}
# {'name': 'magikarp'}
# {'name': 'gyarados'}
# {'name': 'lapras'}
# {'name': 'ditto'}
# {'name': 'eevee'}
# {'name': 'vaporeon'}
# {'name': 'jolteon'}
# {'name': 'flareon'}
# {'name': 'porygon'}
# {'name': 'omanyte'}
# {'name': 'omastar'}
# {'name': 'kabuto'}
# {'name': 'kabutops'}
# {'name': 'aerodactyl'}
# {'name': 'snorlax'}
# {'name': 'articuno'}
# {'name': 'zapdos'}
# {'name': 'moltres'}
# {'name': 'dratini'}
# {'name': 'dragonair'}
# {'name': 'dragonite'}
# {'name': 'mewtwo'}
# {'name': 'mew'}
# {'name': 'Charmander'}
# {'name': 'Bulbasaur'}
# {'name': 'Squirtle'}

# %% [markdown]
# Delete all entries without a secondary type.

# %%
d = poke_collection.delete_many({'secondary_type':'None'})
print(d.deleted_count)
# Out:
# 2

# %%
q = poke_collection.find({}, {'name':1, '_id':0})
for i in q:
    print(i)
# Out:
# {'name': 'bulbasaur'}
# {'name': 'ivysaur'}
# {'name': 'venusaur'}
# {'name': 'charmander'}
# {'name': 'charmeleon'}
# {'name': 'charizard'}
# {'name': 'squirtle'}
# {'name': 'wartortle'}
# {'name': 'blastoise'}
# {'name': 'bulbasaur'}
# {'name': 'ivysaur'}
# {'name': 'venusaur'}
# {'name': 'charmander'}
# {'name': 'charmeleon'}
# {'name': 'charizard'}
# {'name': 'squirtle'}
# {'name': 'wartortle'}
# {'name': 'blastoise'}
# {'name': 'bulbasaur'}
# {'name': 'ivysaur'}
# {'name': 'venusaur'}
# {'name': 'charmander'}
# {'name': 'charmeleon'}
# {'name': 'charizard'}
# {'name': 'squirtle'}
# {'name': 'wartortle'}
# {'name': 'blastoise'}
# {'name': 'caterpie'}
# {'name': 'metapod'}
# {'name': 'butterfree'}
# {'name': 'weedle'}
# {'name': 'kakuna'}
# {'name': 'beedrill'}
# {'name': 'pidgey'}
# {'name': 'pidgeotto'}
# {'name': 'pidgeot'}
# {'name': 'rattata'}
# {'name': 'raticate'}
# {'name': 'spearow'}
# {'name': 'fearow'}
# {'name': 'ekans'}
# {'name': 'arbok'}
# {'name': 'pikachu'}
# {'name': 'raichu'}
# {'name': 'sandshrew'}
# {'name': 'sandslash'}
# {'name': 'nidoran-f'}
# {'name': 'nidorina'}
# {'name': 'nidoqueen'}
# {'name': 'nidoran-m'}
# {'name': 'nidorino'}
# {'name': 'nidoking'}
# {'name': 'clefairy'}
# {'name': 'clefable'}
# {'name': 'vulpix'}
# {'name': 'ninetales'}
# {'name': 'jigglypuff'}
# {'name': 'wigglytuff'}
# {'name': 'zubat'}
# {'name': 'golbat'}
# {'name': 'oddish'}
# {'name': 'gloom'}
# {'name': 'vileplume'}
# {'name': 'paras'}
# {'name': 'parasect'}
# {'name': 'venonat'}
# {'name': 'venomoth'}
# {'name': 'diglett'}
# {'name': 'dugtrio'}
# {'name': 'meowth'}
# {'name': 'persian'}
# {'name': 'psyduck'}
# {'name': 'golduck'}
# {'name': 'mankey'}
# {'name': 'primeape'}
# {'name': 'growlithe'}
# {'name': 'arcanine'}
# {'name': 'poliwag'}
# {'name': 'poliwhirl'}
# {'name': 'poliwrath'}
# {'name': 'abra'}
# {'name': 'kadabra'}
# {'name': 'alakazam'}
# {'name': 'machop'}
# {'name': 'machoke'}
# {'name': 'machamp'}
# {'name': 'bellsprout'}
# {'name': 'weepinbell'}
# {'name': 'victreebel'}
# {'name': 'tentacool'}
# {'name': 'tentacruel'}
# {'name': 'geodude'}
# {'name': 'graveler'}
# {'name': 'golem'}
# {'name': 'ponyta'}
# {'name': 'rapidash'}
# {'name': 'slowpoke'}
# {'name': 'slowbro'}
# {'name': 'magnemite'}
# {'name': 'magneton'}
# {'name': 'farfetchd'}
# {'name': 'doduo'}
# {'name': 'dodrio'}
# {'name': 'seel'}
# {'name': 'dewgong'}
# {'name': 'grimer'}
# {'name': 'muk'}
# {'name': 'shellder'}
# {'name': 'cloyster'}
# {'name': 'gastly'}
# {'name': 'haunter'}
# {'name': 'gengar'}
# {'name': 'onix'}
# {'name': 'drowzee'}
# {'name': 'hypno'}
# {'name': 'krabby'}
# {'name': 'kingler'}
# {'name': 'voltorb'}
# {'name': 'electrode'}
# {'name': 'exeggcute'}
# {'name': 'exeggutor'}
# {'name': 'cubone'}
# {'name': 'marowak'}
# {'name': 'hitmonlee'}
# {'name': 'hitmonchan'}
# {'name': 'lickitung'}
# {'name': 'koffing'}
# {'name': 'weezing'}
# {'name': 'rhyhorn'}
# {'name': 'rhydon'}
# {'name': 'chansey'}
# {'name': 'tangela'}
# {'name': 'kangaskhan'}
# {'name': 'horsea'}
# {'name': 'seadra'}
# {'name': 'goldeen'}
# {'name': 'seaking'}
# {'name': 'staryu'}
# {'name': 'starmie'}
# {'name': 'mr-mime'}
# {'name': 'scyther'}
# {'name': 'jynx'}
# {'name': 'electabuzz'}
# {'name': 'magmar'}
# {'name': 'pinsir'}
# {'name': 'tauros'}
# {'name': 'magikarp'}
# {'name': 'gyarados'}
# {'name': 'lapras'}
# {'name': 'ditto'}
# {'name': 'eevee'}
# {'name': 'vaporeon'}
# {'name': 'jolteon'}
# {'name': 'flareon'}
# {'name': 'porygon'}
# {'name': 'omanyte'}
# {'name': 'omastar'}
# {'name': 'kabuto'}
# {'name': 'kabutops'}
# {'name': 'aerodactyl'}
# {'name': 'snorlax'}
# {'name': 'articuno'}
# {'name': 'zapdos'}
# {'name': 'moltres'}
# {'name': 'dratini'}
# {'name': 'dragonair'}
# {'name': 'dragonite'}
# {'name': 'mewtwo'}
# {'name': 'mew'}
# {'name': 'bulbasaur'}
# {'name': 'ivysaur'}
# {'name': 'venusaur'}
# {'name': 'charmander'}
# {'name': 'charmeleon'}
# {'name': 'charizard'}
# {'name': 'squirtle'}
# {'name': 'wartortle'}
# {'name': 'blastoise'}
# {'name': 'caterpie'}
# {'name': 'metapod'}
# {'name': 'butterfree'}
# {'name': 'weedle'}
# {'name': 'kakuna'}
# {'name': 'beedrill'}
# {'name': 'pidgey'}
# {'name': 'pidgeotto'}
# {'name': 'pidgeot'}
# {'name': 'rattata'}
# {'name': 'raticate'}
# {'name': 'spearow'}
# {'name': 'fearow'}
# {'name': 'ekans'}
# {'name': 'arbok'}
# {'name': 'pikachu'}
# {'name': 'raichu'}
# {'name': 'sandshrew'}
# {'name': 'sandslash'}
# {'name': 'nidoran-f'}
# {'name': 'nidorina'}
# {'name': 'nidoqueen'}
# {'name': 'nidoran-m'}
# {'name': 'nidorino'}
# {'name': 'nidoking'}
# {'name': 'clefairy'}
# {'name': 'clefable'}
# {'name': 'vulpix'}
# {'name': 'ninetales'}
# {'name': 'jigglypuff'}
# {'name': 'wigglytuff'}
# {'name': 'zubat'}
# {'name': 'golbat'}
# {'name': 'oddish'}
# {'name': 'gloom'}
# {'name': 'vileplume'}
# {'name': 'paras'}
# {'name': 'parasect'}
# {'name': 'venonat'}
# {'name': 'venomoth'}
# {'name': 'diglett'}
# {'name': 'dugtrio'}
# {'name': 'meowth'}
# {'name': 'persian'}
# {'name': 'psyduck'}
# {'name': 'golduck'}
# {'name': 'mankey'}
# {'name': 'primeape'}
# {'name': 'growlithe'}
# {'name': 'arcanine'}
# {'name': 'poliwag'}
# {'name': 'poliwhirl'}
# {'name': 'poliwrath'}
# {'name': 'abra'}
# {'name': 'kadabra'}
# {'name': 'alakazam'}
# {'name': 'machop'}
# {'name': 'machoke'}
# {'name': 'machamp'}
# {'name': 'bellsprout'}
# {'name': 'weepinbell'}
# {'name': 'victreebel'}
# {'name': 'tentacool'}
# {'name': 'tentacruel'}
# {'name': 'geodude'}
# {'name': 'graveler'}
# {'name': 'golem'}
# {'name': 'ponyta'}
# {'name': 'rapidash'}
# {'name': 'slowpoke'}
# {'name': 'slowbro'}
# {'name': 'magnemite'}
# {'name': 'magneton'}
# {'name': 'farfetchd'}
# {'name': 'doduo'}
# {'name': 'dodrio'}
# {'name': 'seel'}
# {'name': 'dewgong'}
# {'name': 'grimer'}
# {'name': 'muk'}
# {'name': 'shellder'}
# {'name': 'cloyster'}
# {'name': 'gastly'}
# {'name': 'haunter'}
# {'name': 'gengar'}
# {'name': 'onix'}
# {'name': 'drowzee'}
# {'name': 'hypno'}
# {'name': 'krabby'}
# {'name': 'kingler'}
# {'name': 'voltorb'}
# {'name': 'electrode'}
# {'name': 'exeggcute'}
# {'name': 'exeggutor'}
# {'name': 'cubone'}
# {'name': 'marowak'}
# {'name': 'hitmonlee'}
# {'name': 'hitmonchan'}
# {'name': 'lickitung'}
# {'name': 'koffing'}
# {'name': 'weezing'}
# {'name': 'rhyhorn'}
# {'name': 'rhydon'}
# {'name': 'chansey'}
# {'name': 'tangela'}
# {'name': 'kangaskhan'}
# {'name': 'horsea'}
# {'name': 'seadra'}
# {'name': 'goldeen'}
# {'name': 'seaking'}
# {'name': 'staryu'}
# {'name': 'starmie'}
# {'name': 'mr-mime'}
# {'name': 'scyther'}
# {'name': 'jynx'}
# {'name': 'electabuzz'}
# {'name': 'magmar'}
# {'name': 'pinsir'}
# {'name': 'tauros'}
# {'name': 'magikarp'}
# {'name': 'gyarados'}
# {'name': 'lapras'}
# {'name': 'ditto'}
# {'name': 'eevee'}
# {'name': 'vaporeon'}
# {'name': 'jolteon'}
# {'name': 'flareon'}
# {'name': 'porygon'}
# {'name': 'omanyte'}
# {'name': 'omastar'}
# {'name': 'kabuto'}
# {'name': 'kabutops'}
# {'name': 'aerodactyl'}
# {'name': 'snorlax'}
# {'name': 'articuno'}
# {'name': 'zapdos'}
# {'name': 'moltres'}
# {'name': 'dratini'}
# {'name': 'dragonair'}
# {'name': 'dragonite'}
# {'name': 'mewtwo'}
# {'name': 'mew'}
# {'name': 'bulbasaur'}
# {'name': 'ivysaur'}
# {'name': 'venusaur'}
# {'name': 'charmander'}
# {'name': 'charmeleon'}
# {'name': 'charizard'}
# {'name': 'squirtle'}
# {'name': 'wartortle'}
# {'name': 'blastoise'}
# {'name': 'caterpie'}
# {'name': 'metapod'}
# {'name': 'butterfree'}
# {'name': 'weedle'}
# {'name': 'kakuna'}
# {'name': 'beedrill'}
# {'name': 'pidgey'}
# {'name': 'pidgeotto'}
# {'name': 'pidgeot'}
# {'name': 'rattata'}
# {'name': 'raticate'}
# {'name': 'spearow'}
# {'name': 'fearow'}
# {'name': 'ekans'}
# {'name': 'arbok'}
# {'name': 'pikachu'}
# {'name': 'raichu'}
# {'name': 'sandshrew'}
# {'name': 'sandslash'}
# {'name': 'nidoran-f'}
# {'name': 'nidorina'}
# {'name': 'nidoqueen'}
# {'name': 'nidoran-m'}
# {'name': 'nidorino'}
# {'name': 'nidoking'}
# {'name': 'clefairy'}
# {'name': 'clefable'}
# {'name': 'vulpix'}
# {'name': 'ninetales'}
# {'name': 'jigglypuff'}
# {'name': 'wigglytuff'}
# {'name': 'zubat'}
# {'name': 'golbat'}
# {'name': 'oddish'}
# {'name': 'gloom'}
# {'name': 'vileplume'}
# {'name': 'paras'}
# {'name': 'parasect'}
# {'name': 'venonat'}
# {'name': 'venomoth'}
# {'name': 'diglett'}
# {'name': 'dugtrio'}
# {'name': 'meowth'}
# {'name': 'persian'}
# {'name': 'psyduck'}
# {'name': 'golduck'}
# {'name': 'mankey'}
# {'name': 'primeape'}
# {'name': 'growlithe'}
# {'name': 'arcanine'}
# {'name': 'poliwag'}
# {'name': 'poliwhirl'}
# {'name': 'poliwrath'}
# {'name': 'abra'}
# {'name': 'kadabra'}
# {'name': 'alakazam'}
# {'name': 'machop'}
# {'name': 'machoke'}
# {'name': 'machamp'}
# {'name': 'bellsprout'}
# {'name': 'weepinbell'}
# {'name': 'victreebel'}
# {'name': 'tentacool'}
# {'name': 'tentacruel'}
# {'name': 'geodude'}
# {'name': 'graveler'}
# {'name': 'golem'}
# {'name': 'ponyta'}
# {'name': 'rapidash'}
# {'name': 'slowpoke'}
# {'name': 'slowbro'}
# {'name': 'magnemite'}
# {'name': 'magneton'}
# {'name': 'farfetchd'}
# {'name': 'doduo'}
# {'name': 'dodrio'}
# {'name': 'seel'}
# {'name': 'dewgong'}
# {'name': 'grimer'}
# {'name': 'muk'}
# {'name': 'shellder'}
# {'name': 'cloyster'}
# {'name': 'gastly'}
# {'name': 'haunter'}
# {'name': 'gengar'}
# {'name': 'onix'}
# {'name': 'drowzee'}
# {'name': 'hypno'}
# {'name': 'krabby'}
# {'name': 'kingler'}
# {'name': 'voltorb'}
# {'name': 'electrode'}
# {'name': 'exeggcute'}
# {'name': 'exeggutor'}
# {'name': 'cubone'}
# {'name': 'marowak'}
# {'name': 'hitmonlee'}
# {'name': 'hitmonchan'}
# {'name': 'lickitung'}
# {'name': 'koffing'}
# {'name': 'weezing'}
# {'name': 'rhyhorn'}
# {'name': 'rhydon'}
# {'name': 'chansey'}
# {'name': 'tangela'}
# {'name': 'kangaskhan'}
# {'name': 'horsea'}
# {'name': 'seadra'}
# {'name': 'goldeen'}
# {'name': 'seaking'}
# {'name': 'staryu'}
# {'name': 'starmie'}
# {'name': 'mr-mime'}
# {'name': 'scyther'}
# {'name': 'jynx'}
# {'name': 'electabuzz'}
# {'name': 'magmar'}
# {'name': 'pinsir'}
# {'name': 'tauros'}
# {'name': 'magikarp'}
# {'name': 'gyarados'}
# {'name': 'lapras'}
# {'name': 'ditto'}
# {'name': 'eevee'}
# {'name': 'vaporeon'}
# {'name': 'jolteon'}
# {'name': 'flareon'}
# {'name': 'porygon'}
# {'name': 'omanyte'}
# {'name': 'omastar'}
# {'name': 'kabuto'}
# {'name': 'kabutops'}
# {'name': 'aerodactyl'}
# {'name': 'snorlax'}
# {'name': 'articuno'}
# {'name': 'zapdos'}
# {'name': 'moltres'}
# {'name': 'dratini'}
# {'name': 'dragonair'}
# {'name': 'dragonite'}
# {'name': 'mewtwo'}
# {'name': 'mew'}
# {'name': 'bulbasaur'}
# {'name': 'ivysaur'}
# {'name': 'venusaur'}
# {'name': 'charmander'}
# {'name': 'charmeleon'}
# {'name': 'charizard'}
# {'name': 'squirtle'}
# {'name': 'wartortle'}
# {'name': 'blastoise'}
# {'name': 'caterpie'}
# {'name': 'metapod'}
# {'name': 'butterfree'}
# {'name': 'weedle'}
# {'name': 'kakuna'}
# {'name': 'beedrill'}
# {'name': 'pidgey'}
# {'name': 'pidgeotto'}
# {'name': 'pidgeot'}
# {'name': 'rattata'}
# {'name': 'raticate'}
# {'name': 'spearow'}
# {'name': 'fearow'}
# {'name': 'ekans'}
# {'name': 'arbok'}
# {'name': 'pikachu'}
# {'name': 'raichu'}
# {'name': 'sandshrew'}
# {'name': 'sandslash'}
# {'name': 'nidoran-f'}
# {'name': 'nidorina'}
# {'name': 'nidoqueen'}
# {'name': 'nidoran-m'}
# {'name': 'nidorino'}
# {'name': 'nidoking'}
# {'name': 'clefairy'}
# {'name': 'clefable'}
# {'name': 'vulpix'}
# {'name': 'ninetales'}
# {'name': 'jigglypuff'}
# {'name': 'wigglytuff'}
# {'name': 'zubat'}
# {'name': 'golbat'}
# {'name': 'oddish'}
# {'name': 'gloom'}
# {'name': 'vileplume'}
# {'name': 'paras'}
# {'name': 'parasect'}
# {'name': 'venonat'}
# {'name': 'venomoth'}
# {'name': 'diglett'}
# {'name': 'dugtrio'}
# {'name': 'meowth'}
# {'name': 'persian'}
# {'name': 'psyduck'}
# {'name': 'golduck'}
# {'name': 'mankey'}
# {'name': 'primeape'}
# {'name': 'growlithe'}
# {'name': 'arcanine'}
# {'name': 'poliwag'}
# {'name': 'poliwhirl'}
# {'name': 'poliwrath'}
# {'name': 'abra'}
# {'name': 'kadabra'}
# {'name': 'alakazam'}
# {'name': 'machop'}
# {'name': 'machoke'}
# {'name': 'machamp'}
# {'name': 'bellsprout'}
# {'name': 'weepinbell'}
# {'name': 'victreebel'}
# {'name': 'tentacool'}
# {'name': 'tentacruel'}
# {'name': 'geodude'}
# {'name': 'graveler'}
# {'name': 'golem'}
# {'name': 'ponyta'}
# {'name': 'rapidash'}
# {'name': 'slowpoke'}
# {'name': 'slowbro'}
# {'name': 'magnemite'}
# {'name': 'magneton'}
# {'name': 'farfetchd'}
# {'name': 'doduo'}
# {'name': 'dodrio'}
# {'name': 'seel'}
# {'name': 'dewgong'}
# {'name': 'grimer'}
# {'name': 'muk'}
# {'name': 'shellder'}
# {'name': 'cloyster'}
# {'name': 'gastly'}
# {'name': 'haunter'}
# {'name': 'gengar'}
# {'name': 'onix'}
# {'name': 'drowzee'}
# {'name': 'hypno'}
# {'name': 'krabby'}
# {'name': 'kingler'}
# {'name': 'voltorb'}
# {'name': 'electrode'}
# {'name': 'exeggcute'}
# {'name': 'exeggutor'}
# {'name': 'cubone'}
# {'name': 'marowak'}
# {'name': 'hitmonlee'}
# {'name': 'hitmonchan'}
# {'name': 'lickitung'}
# {'name': 'koffing'}
# {'name': 'weezing'}
# {'name': 'rhyhorn'}
# {'name': 'rhydon'}
# {'name': 'chansey'}
# {'name': 'tangela'}
# {'name': 'kangaskhan'}
# {'name': 'horsea'}
# {'name': 'seadra'}
# {'name': 'goldeen'}
# {'name': 'seaking'}
# {'name': 'staryu'}
# {'name': 'starmie'}
# {'name': 'mr-mime'}
# {'name': 'scyther'}
# {'name': 'jynx'}
# {'name': 'electabuzz'}
# {'name': 'magmar'}
# {'name': 'pinsir'}
# {'name': 'tauros'}
# {'name': 'magikarp'}
# {'name': 'gyarados'}
# {'name': 'lapras'}
# {'name': 'ditto'}
# {'name': 'eevee'}
# {'name': 'vaporeon'}
# {'name': 'jolteon'}
# {'name': 'flareon'}
# {'name': 'porygon'}
# {'name': 'omanyte'}
# {'name': 'omastar'}
# {'name': 'kabuto'}
# {'name': 'kabutops'}
# {'name': 'aerodactyl'}
# {'name': 'snorlax'}
# {'name': 'articuno'}
# {'name': 'zapdos'}
# {'name': 'moltres'}
# {'name': 'dratini'}
# {'name': 'dragonair'}
# {'name': 'dragonite'}
# {'name': 'mewtwo'}
# {'name': 'mew'}
# {'name': 'bulbasaur'}
# {'name': 'ivysaur'}
# {'name': 'venusaur'}
# {'name': 'charmander'}
# {'name': 'charmeleon'}
# {'name': 'charizard'}
# {'name': 'squirtle'}
# {'name': 'wartortle'}
# {'name': 'blastoise'}
# {'name': 'caterpie'}
# {'name': 'metapod'}
# {'name': 'butterfree'}
# {'name': 'weedle'}
# {'name': 'kakuna'}
# {'name': 'beedrill'}
# {'name': 'pidgey'}
# {'name': 'pidgeotto'}
# {'name': 'pidgeot'}
# {'name': 'rattata'}
# {'name': 'raticate'}
# {'name': 'spearow'}
# {'name': 'fearow'}
# {'name': 'ekans'}
# {'name': 'arbok'}
# {'name': 'pikachu'}
# {'name': 'raichu'}
# {'name': 'sandshrew'}
# {'name': 'sandslash'}
# {'name': 'nidoran-f'}
# {'name': 'nidorina'}
# {'name': 'nidoqueen'}
# {'name': 'nidoran-m'}
# {'name': 'nidorino'}
# {'name': 'nidoking'}
# {'name': 'clefairy'}
# {'name': 'clefable'}
# {'name': 'vulpix'}
# {'name': 'ninetales'}
# {'name': 'jigglypuff'}
# {'name': 'wigglytuff'}
# {'name': 'zubat'}
# {'name': 'golbat'}
# {'name': 'oddish'}
# {'name': 'gloom'}
# {'name': 'vileplume'}
# {'name': 'paras'}
# {'name': 'parasect'}
# {'name': 'venonat'}
# {'name': 'venomoth'}
# {'name': 'diglett'}
# {'name': 'dugtrio'}
# {'name': 'meowth'}
# {'name': 'persian'}
# {'name': 'psyduck'}
# {'name': 'golduck'}
# {'name': 'mankey'}
# {'name': 'primeape'}
# {'name': 'growlithe'}
# {'name': 'arcanine'}
# {'name': 'poliwag'}
# {'name': 'poliwhirl'}
# {'name': 'poliwrath'}
# {'name': 'abra'}
# {'name': 'kadabra'}
# {'name': 'alakazam'}
# {'name': 'machop'}
# {'name': 'machoke'}
# {'name': 'machamp'}
# {'name': 'bellsprout'}
# {'name': 'weepinbell'}
# {'name': 'victreebel'}
# {'name': 'tentacool'}
# {'name': 'tentacruel'}
# {'name': 'geodude'}
# {'name': 'graveler'}
# {'name': 'golem'}
# {'name': 'ponyta'}
# {'name': 'rapidash'}
# {'name': 'slowpoke'}
# {'name': 'slowbro'}
# {'name': 'magnemite'}
# {'name': 'magneton'}
# {'name': 'farfetchd'}
# {'name': 'doduo'}
# {'name': 'dodrio'}
# {'name': 'seel'}
# {'name': 'dewgong'}
# {'name': 'grimer'}
# {'name': 'muk'}
# {'name': 'shellder'}
# {'name': 'cloyster'}
# {'name': 'gastly'}
# {'name': 'haunter'}
# {'name': 'gengar'}
# {'name': 'onix'}
# {'name': 'drowzee'}
# {'name': 'hypno'}
# {'name': 'krabby'}
# {'name': 'kingler'}
# {'name': 'voltorb'}
# {'name': 'electrode'}
# {'name': 'exeggcute'}
# {'name': 'exeggutor'}
# {'name': 'cubone'}
# {'name': 'marowak'}
# {'name': 'hitmonlee'}
# {'name': 'hitmonchan'}
# {'name': 'lickitung'}
# {'name': 'koffing'}
# {'name': 'weezing'}
# {'name': 'rhyhorn'}
# {'name': 'rhydon'}
# {'name': 'chansey'}
# {'name': 'tangela'}
# {'name': 'kangaskhan'}
# {'name': 'horsea'}
# {'name': 'seadra'}
# {'name': 'goldeen'}
# {'name': 'seaking'}
# {'name': 'staryu'}
# {'name': 'starmie'}
# {'name': 'mr-mime'}
# {'name': 'scyther'}
# {'name': 'jynx'}
# {'name': 'electabuzz'}
# {'name': 'magmar'}
# {'name': 'pinsir'}
# {'name': 'tauros'}
# {'name': 'magikarp'}
# {'name': 'gyarados'}
# {'name': 'lapras'}
# {'name': 'ditto'}
# {'name': 'eevee'}
# {'name': 'vaporeon'}
# {'name': 'jolteon'}
# {'name': 'flareon'}
# {'name': 'porygon'}
# {'name': 'omanyte'}
# {'name': 'omastar'}
# {'name': 'kabuto'}
# {'name': 'kabutops'}
# {'name': 'aerodactyl'}
# {'name': 'snorlax'}
# {'name': 'articuno'}
# {'name': 'zapdos'}
# {'name': 'moltres'}
# {'name': 'dratini'}
# {'name': 'dragonair'}
# {'name': 'dragonite'}
# {'name': 'mewtwo'}
# {'name': 'mew'}
# {'name': 'bulbasaur'}
# {'name': 'ivysaur'}
# {'name': 'venusaur'}
# {'name': 'charmander'}
# {'name': 'charmeleon'}
# {'name': 'charizard'}
# {'name': 'squirtle'}
# {'name': 'wartortle'}
# {'name': 'blastoise'}
# {'name': 'caterpie'}
# {'name': 'metapod'}
# {'name': 'butterfree'}
# {'name': 'weedle'}
# {'name': 'kakuna'}
# {'name': 'beedrill'}
# {'name': 'pidgey'}
# {'name': 'pidgeotto'}
# {'name': 'pidgeot'}
# {'name': 'rattata'}
# {'name': 'raticate'}
# {'name': 'spearow'}
# {'name': 'fearow'}
# {'name': 'ekans'}
# {'name': 'arbok'}
# {'name': 'pikachu'}
# {'name': 'raichu'}
# {'name': 'sandshrew'}
# {'name': 'sandslash'}
# {'name': 'nidoran-f'}
# {'name': 'nidorina'}
# {'name': 'nidoqueen'}
# {'name': 'nidoran-m'}
# {'name': 'nidorino'}
# {'name': 'nidoking'}
# {'name': 'clefairy'}
# {'name': 'clefable'}
# {'name': 'vulpix'}
# {'name': 'ninetales'}
# {'name': 'jigglypuff'}
# {'name': 'wigglytuff'}
# {'name': 'zubat'}
# {'name': 'golbat'}
# {'name': 'oddish'}
# {'name': 'gloom'}
# {'name': 'vileplume'}
# {'name': 'paras'}
# {'name': 'parasect'}
# {'name': 'venonat'}
# {'name': 'venomoth'}
# {'name': 'diglett'}
# {'name': 'dugtrio'}
# {'name': 'meowth'}
# {'name': 'persian'}
# {'name': 'psyduck'}
# {'name': 'golduck'}
# {'name': 'mankey'}
# {'name': 'primeape'}
# {'name': 'growlithe'}
# {'name': 'arcanine'}
# {'name': 'poliwag'}
# {'name': 'poliwhirl'}
# {'name': 'poliwrath'}
# {'name': 'abra'}
# {'name': 'kadabra'}
# {'name': 'alakazam'}
# {'name': 'machop'}
# {'name': 'machoke'}
# {'name': 'machamp'}
# {'name': 'bellsprout'}
# {'name': 'weepinbell'}
# {'name': 'victreebel'}
# {'name': 'tentacool'}
# {'name': 'tentacruel'}
# {'name': 'geodude'}
# {'name': 'graveler'}
# {'name': 'golem'}
# {'name': 'ponyta'}
# {'name': 'rapidash'}
# {'name': 'slowpoke'}
# {'name': 'slowbro'}
# {'name': 'magnemite'}
# {'name': 'magneton'}
# {'name': 'farfetchd'}
# {'name': 'doduo'}
# {'name': 'dodrio'}
# {'name': 'seel'}
# {'name': 'dewgong'}
# {'name': 'grimer'}
# {'name': 'muk'}
# {'name': 'shellder'}
# {'name': 'cloyster'}
# {'name': 'gastly'}
# {'name': 'haunter'}
# {'name': 'gengar'}
# {'name': 'onix'}
# {'name': 'drowzee'}
# {'name': 'hypno'}
# {'name': 'krabby'}
# {'name': 'kingler'}
# {'name': 'voltorb'}
# {'name': 'electrode'}
# {'name': 'exeggcute'}
# {'name': 'exeggutor'}
# {'name': 'cubone'}
# {'name': 'marowak'}
# {'name': 'hitmonlee'}
# {'name': 'hitmonchan'}
# {'name': 'lickitung'}
# {'name': 'koffing'}
# {'name': 'weezing'}
# {'name': 'rhyhorn'}
# {'name': 'rhydon'}
# {'name': 'chansey'}
# {'name': 'tangela'}
# {'name': 'kangaskhan'}
# {'name': 'horsea'}
# {'name': 'seadra'}
# {'name': 'goldeen'}
# {'name': 'seaking'}
# {'name': 'staryu'}
# {'name': 'starmie'}
# {'name': 'mr-mime'}
# {'name': 'scyther'}
# {'name': 'jynx'}
# {'name': 'electabuzz'}
# {'name': 'magmar'}
# {'name': 'pinsir'}
# {'name': 'tauros'}
# {'name': 'magikarp'}
# {'name': 'gyarados'}
# {'name': 'lapras'}
# {'name': 'ditto'}
# {'name': 'eevee'}
# {'name': 'vaporeon'}
# {'name': 'jolteon'}
# {'name': 'flareon'}
# {'name': 'porygon'}
# {'name': 'omanyte'}
# {'name': 'omastar'}
# {'name': 'kabuto'}
# {'name': 'kabutops'}
# {'name': 'aerodactyl'}
# {'name': 'snorlax'}
# {'name': 'articuno'}
# {'name': 'zapdos'}
# {'name': 'moltres'}
# {'name': 'dratini'}
# {'name': 'dragonair'}
# {'name': 'dragonite'}
# {'name': 'mewtwo'}
# {'name': 'mew'}
# {'name': 'Bulbasaur'}

# %% [markdown]
# Delete the entire collection.

# %%
d = poke_collection.delete_many({})

# %%
q = poke_collection.find({}, {'name':1, '_id':0})
for i in q:
    print(i)

# %% [markdown]
# ## ETL

# %% [markdown]
# ### Extract data from API

# %% [markdown]
# Documentation - https://pokeapi.co/docs/v2.html

# %% [markdown]
# Create base URL.

# %%
base_url = 'https://pokeapi.co/api/v2'

# %% [markdown]
# Create URL to get info on Pikachu. Make request to URL and check response keys.

# %%
pika_url = base_url + '/pokemon/pikachu'
response = requests.get(pika_url)
pika_json = response.json()
pika_json.keys()
# Out:
# dict_keys(['abilities', 'base_experience', 'forms', 'game_indices', 'height', 'held_items', 'id', 'is_default', 'location_area_encounters', 'moves', 'name', 'order', 'species', 'sprites', 'stats', 'types', 'weight'])

# %% [markdown]
# Get the name, primary type, and secondary type.

# %%
name = pika_json['name']

types = pika_json['types']

type1 = types[0]['type']['name']
type1_url = types[0]['type']['url']

type2 = None if len(types)<2 else types[1]['type']['name']
type2_url = None if len(types)<2 else types[1]['type']['url']

print(name, type1, type1_url, type2, type2_url)
# Out:
# pikachu electric https://pokeapi.co/api/v2/type/13/ None None

# %% [markdown]
# Now we want to find the types Pikachu is weak to.

# %% [markdown]
# Using the '/type' endpoint, find info on the electric type.

# %%
url = 'https://pokeapi.co/api/v2/type/electric'
response = requests.get(url).json()
response.keys()
# Out:
# dict_keys(['damage_relations', 'game_indices', 'generation', 'id', 'move_damage_class', 'moves', 'name', 'names', 'pokemon'])

# %% [markdown]
# Check the 'damage_relations' dictionary.

# %%
response['damage_relations'].keys()
# Out:
# dict_keys(['double_damage_from', 'double_damage_to', 'half_damage_from', 'half_damage_to', 'no_damage_from', 'no_damage_to'])

# %% [markdown]
# Grab the types supereffective against electric from the 'double_damage_from' key. Iterate through to get the weaknesses.

# %%
response['damage_relations']['double_damage_from']
# Out:
# [{'name': 'ground', 'url': 'https://pokeapi.co/api/v2/type/5/'}]

# %%
weaknesses = [i['name'] for i in response['damage_relations']['double_damage_from']]
weaknesses
# Out:
# ['ground']

# %% [markdown]
# # <center> Activity

# %% [markdown]
# <img src='pokedex.png'>

# %% [markdown]
# Professor Oak has tasked you with compiling info on Pokemon. Using the PokeAPI, extract data on all 151 original Pokemon and load that data into a Mongo database. <br>
# <br>
# You should include the following info for each Pokemon:
#     - Name
#     - Height
#     - Weight
#     - Primary type
#     - Secondary Type
#     - Weaknesses
#     - Moves

# %% [markdown]
# <b>Note</b>: For weaknesses, make sure you look at both the primary type and secondary type. The list should only contain each weaknesses once even if both the primary and secondary types share a weaknesses (maybe use a Python set).

# %% [markdown]
# <b>Hint</b>: The first 151 Pokemon have IDs from 1-151. You can use that to collect info on each one in a loop.

# %%
base_url = 'https://pokeapi.co/api/v2'

# %%
client = pymongo.MongoClient("mongodb://127.0.0.1:27017/")
poke_db = client['pokemon_db']
poke_collection = poke_db['pokemon_collection']
for x in range(1,152):
    pokemon_url = base_url + '/pokemon/' + str(x)
    response = requests.get(pokemon_url)
    pokemon = response.json()
    
    #getting primary and secondary types
    types = pokemon['types']
    type1 = types[0]['type']['name']
    type1_url = types[0]['type']['url']
    type2 = None if len(types)<2 else types[1]['type']['name']
    type2_url = None if len(types)<2 else types[1]['type']['url']
    
    #getting weaknesses data
    weakurl_type1 = 'https://pokeapi.co/api/v2/type/' + str(type1)
    weaknesses1 = requests.get(weakurl_type1).json()
    weaknesses2 = None if len(types)<2 else requests.get('https://pokeapi.co/api/v2/type/' + str(type2)).json()
    
    #compile weaknesses data
    all_weaknesses = []
    for i in weaknesses1['damage_relations']['double_damage_from']:
        all_weaknesses.append(i['name'])
    if weaknesses2:
        for i in weaknesses2['damage_relations']['double_damage_from']:
            if i not in all_weaknesses:
                all_weaknesses.append(i['name'])
            else:
                pass
    
    pokemonmongo = {'name': pokemon['name'], 'Height': pokemon['height'], 'Weight': pokemon['weight'],
                    'Primary type': type1, 'Secondary type': type2,
                    'Weaknesses': all_weaknesses,
                    'Moves': [i['move']['name'] for i in pokemon['moves']]}
    results = poke_collection.insert_one(pokemonmongo)

# %%
q = poke_collection.find({}, {'_id': 0, 'name': 1, 'Primary type': 1, 'Secondary type': 1, 'Weaknesses': 1})
for i in q:
    print(i)
# Out:
# {'name': 'bulbasaur', 'Primary type': 'poison', 'Secondary type': 'grass', 'Weaknesses': ['ground', 'psychic', 'flying', 'poison', 'bug', 'fire', 'ice']}
# {'name': 'ivysaur', 'Primary type': 'poison', 'Secondary type': 'grass', 'Weaknesses': ['ground', 'psychic', 'flying', 'poison', 'bug', 'fire', 'ice']}
# {'name': 'venusaur', 'Primary type': 'poison', 'Secondary type': 'grass', 'Weaknesses': ['ground', 'psychic', 'flying', 'poison', 'bug', 'fire', 'ice']}
# {'name': 'charmander', 'Primary type': 'fire', 'Secondary type': None, 'Weaknesses': ['ground', 'rock', 'water']}
# {'name': 'charmeleon', 'Primary type': 'fire', 'Secondary type': None, 'Weaknesses': ['ground', 'rock', 'water']}
# {'name': 'charizard', 'Primary type': 'flying', 'Secondary type': 'fire', 'Weaknesses': ['rock', 'electric', 'ice', 'ground', 'rock', 'water']}
# {'name': 'squirtle', 'Primary type': 'water', 'Secondary type': None, 'Weaknesses': ['grass', 'electric']}
# {'name': 'wartortle', 'Primary type': 'water', 'Secondary type': None, 'Weaknesses': ['grass', 'electric']}
# {'name': 'blastoise', 'Primary type': 'water', 'Secondary type': None, 'Weaknesses': ['grass', 'electric']}
# {'name': 'caterpie', 'Primary type': 'bug', 'Secondary type': None, 'Weaknesses': ['flying', 'rock', 'fire']}
# {'name': 'metapod', 'Primary type': 'bug', 'Secondary type': None, 'Weaknesses': ['flying', 'rock', 'fire']}
# {'name': 'butterfree', 'Primary type': 'flying', 'Secondary type': 'bug', 'Weaknesses': ['rock', 'electric', 'ice', 'flying', 'rock', 'fire']}
# {'name': 'weedle', 'Primary type': 'poison', 'Secondary type': 'bug', 'Weaknesses': ['ground', 'psychic', 'flying', 'rock', 'fire']}
# {'name': 'kakuna', 'Primary type': 'poison', 'Secondary type': 'bug', 'Weaknesses': ['ground', 'psychic', 'flying', 'rock', 'fire']}
# {'name': 'beedrill', 'Primary type': 'poison', 'Secondary type': 'bug', 'Weaknesses': ['ground', 'psychic', 'flying', 'rock', 'fire']}
# {'name': 'pidgey', 'Primary type': 'flying', 'Secondary type': 'normal', 'Weaknesses': ['rock', 'electric', 'ice', 'fighting']}
# {'name': 'pidgeotto', 'Primary type': 'flying', 'Secondary type': 'normal', 'Weaknesses': ['rock', 'electric', 'ice', 'fighting']}
# {'name': 'pidgeot', 'Primary type': 'flying', 'Secondary type': 'normal', 'Weaknesses': ['rock', 'electric', 'ice', 'fighting']}
# {'name': 'rattata', 'Primary type': 'normal', 'Secondary type': None, 'Weaknesses': ['fighting']}
# {'name': 'raticate', 'Primary type': 'normal', 'Secondary type': None, 'Weaknesses': ['fighting']}
# {'name': 'spearow', 'Primary type': 'flying', 'Secondary type': 'normal', 'Weaknesses': ['rock', 'electric', 'ice', 'fighting']}
# {'name': 'fearow', 'Primary type': 'flying', 'Secondary type': 'normal', 'Weaknesses': ['rock', 'electric', 'ice', 'fighting']}
# {'name': 'ekans', 'Primary type': 'poison', 'Secondary type': None, 'Weaknesses': ['ground', 'psychic']}
# {'name': 'arbok', 'Primary type': 'poison', 'Secondary type': None, 'Weaknesses': ['ground', 'psychic']}
# {'name': 'pikachu', 'Primary type': 'electric', 'Secondary type': None, 'Weaknesses': ['ground']}
# {'name': 'raichu', 'Primary type': 'electric', 'Secondary type': None, 'Weaknesses': ['ground']}
# {'name': 'sandshrew', 'Primary type': 'ground', 'Secondary type': None, 'Weaknesses': ['water', 'grass', 'ice']}
# {'name': 'sandslash', 'Primary type': 'ground', 'Secondary type': None, 'Weaknesses': ['water', 'grass', 'ice']}
# {'name': 'nidoran-f', 'Primary type': 'poison', 'Secondary type': None, 'Weaknesses': ['ground', 'psychic']}
# {'name': 'nidorina', 'Primary type': 'poison', 'Secondary type': None, 'Weaknesses': ['ground', 'psychic']}
# {'name': 'nidoqueen', 'Primary type': 'ground', 'Secondary type': 'poison', 'Weaknesses': ['water', 'grass', 'ice', 'ground', 'psychic']}
# {'name': 'nidoran-m', 'Primary type': 'poison', 'Secondary type': None, 'Weaknesses': ['ground', 'psychic']}
# {'name': 'nidorino', 'Primary type': 'poison', 'Secondary type': None, 'Weaknesses': ['ground', 'psychic']}
# {'name': 'nidoking', 'Primary type': 'ground', 'Secondary type': 'poison', 'Weaknesses': ['water', 'grass', 'ice', 'ground', 'psychic']}
# {'name': 'clefairy', 'Primary type': 'fairy', 'Secondary type': None, 'Weaknesses': ['poison', 'steel']}
# {'name': 'clefable', 'Primary type': 'fairy', 'Secondary type': None, 'Weaknesses': ['poison', 'steel']}
# {'name': 'vulpix', 'Primary type': 'fire', 'Secondary type': None, 'Weaknesses': ['ground', 'rock', 'water']}
# {'name': 'ninetales', 'Primary type': 'fire', 'Secondary type': None, 'Weaknesses': ['ground', 'rock', 'water']}
# {'name': 'jigglypuff', 'Primary type': 'fairy', 'Secondary type': 'normal', 'Weaknesses': ['poison', 'steel', 'fighting']}
# {'name': 'wigglytuff', 'Primary type': 'fairy', 'Secondary type': 'normal', 'Weaknesses': ['poison', 'steel', 'fighting']}
# {'name': 'zubat', 'Primary type': 'flying', 'Secondary type': 'poison', 'Weaknesses': ['rock', 'electric', 'ice', 'ground', 'psychic']}
# {'name': 'golbat', 'Primary type': 'flying', 'Secondary type': 'poison', 'Weaknesses': ['rock', 'electric', 'ice', 'ground', 'psychic']}
# {'name': 'oddish', 'Primary type': 'poison', 'Secondary type': 'grass', 'Weaknesses': ['ground', 'psychic', 'flying', 'poison', 'bug', 'fire', 'ice']}
# {'name': 'gloom', 'Primary type': 'poison', 'Secondary type': 'grass', 'Weaknesses': ['ground', 'psychic', 'flying', 'poison', 'bug', 'fire', 'ice']}
# {'name': 'vileplume', 'Primary type': 'poison', 'Secondary type': 'grass', 'Weaknesses': ['ground', 'psychic', 'flying', 'poison', 'bug', 'fire', 'ice']}
# {'name': 'paras', 'Primary type': 'grass', 'Secondary type': 'bug', 'Weaknesses': ['flying', 'poison', 'bug', 'fire', 'ice', 'flying', 'rock', 'fire']}
# {'name': 'parasect', 'Primary type': 'grass', 'Secondary type': 'bug', 'Weaknesses': ['flying', 'poison', 'bug', 'fire', 'ice', 'flying', 'rock', 'fire']}
# {'name': 'venonat', 'Primary type': 'poison', 'Secondary type': 'bug', 'Weaknesses': ['ground', 'psychic', 'flying', 'rock', 'fire']}
# {'name': 'venomoth', 'Primary type': 'poison', 'Secondary type': 'bug', 'Weaknesses': ['ground', 'psychic', 'flying', 'rock', 'fire']}
# {'name': 'diglett', 'Primary type': 'ground', 'Secondary type': None, 'Weaknesses': ['water', 'grass', 'ice']}
# {'name': 'dugtrio', 'Primary type': 'ground', 'Secondary type': None, 'Weaknesses': ['water', 'grass', 'ice']}
# {'name': 'meowth', 'Primary type': 'normal', 'Secondary type': None, 'Weaknesses': ['fighting']}
# {'name': 'persian', 'Primary type': 'normal', 'Secondary type': None, 'Weaknesses': ['fighting']}
# {'name': 'psyduck', 'Primary type': 'water', 'Secondary type': None, 'Weaknesses': ['grass', 'electric']}
# {'name': 'golduck', 'Primary type': 'water', 'Secondary type': None, 'Weaknesses': ['grass', 'electric']}
# {'name': 'mankey', 'Primary type': 'fighting', 'Secondary type': None, 'Weaknesses': ['flying', 'psychic', 'fairy']}
# {'name': 'primeape', 'Primary type': 'fighting', 'Secondary type': None, 'Weaknesses': ['flying', 'psychic', 'fairy']}
# {'name': 'growlithe', 'Primary type': 'fire', 'Secondary type': None, 'Weaknesses': ['ground', 'rock', 'water']}
# {'name': 'arcanine', 'Primary type': 'fire', 'Secondary type': None, 'Weaknesses': ['ground', 'rock', 'water']}
# {'name': 'poliwag', 'Primary type': 'water', 'Secondary type': None, 'Weaknesses': ['grass', 'electric']}
# {'name': 'poliwhirl', 'Primary type': 'water', 'Secondary type': None, 'Weaknesses': ['grass', 'electric']}
# {'name': 'poliwrath', 'Primary type': 'fighting', 'Secondary type': 'water', 'Weaknesses': ['flying', 'psychic', 'fairy', 'grass', 'electric']}
# {'name': 'abra', 'Primary type': 'psychic', 'Secondary type': None, 'Weaknesses': ['bug', 'ghost', 'dark']}
# {'name': 'kadabra', 'Primary type': 'psychic', 'Secondary type': None, 'Weaknesses': ['bug', 'ghost', 'dark']}
# {'name': 'alakazam', 'Primary type': 'psychic', 'Secondary type': None, 'Weaknesses': ['bug', 'ghost', 'dark']}
# {'name': 'machop', 'Primary type': 'fighting', 'Secondary type': None, 'Weaknesses': ['flying', 'psychic', 'fairy']}
# {'name': 'machoke', 'Primary type': 'fighting', 'Secondary type': None, 'Weaknesses': ['flying', 'psychic', 'fairy']}
# {'name': 'machamp', 'Primary type': 'fighting', 'Secondary type': None, 'Weaknesses': ['flying', 'psychic', 'fairy']}
# {'name': 'bellsprout', 'Primary type': 'poison', 'Secondary type': 'grass', 'Weaknesses': ['ground', 'psychic', 'flying', 'poison', 'bug', 'fire', 'ice']}
# {'name': 'weepinbell', 'Primary type': 'poison', 'Secondary type': 'grass', 'Weaknesses': ['ground', 'psychic', 'flying', 'poison', 'bug', 'fire', 'ice']}
# {'name': 'victreebel', 'Primary type': 'poison', 'Secondary type': 'grass', 'Weaknesses': ['ground', 'psychic', 'flying', 'poison', 'bug', 'fire', 'ice']}
# {'name': 'tentacool', 'Primary type': 'poison', 'Secondary type': 'water', 'Weaknesses': ['ground', 'psychic', 'grass', 'electric']}
# {'name': 'tentacruel', 'Primary type': 'poison', 'Secondary type': 'water', 'Weaknesses': ['ground', 'psychic', 'grass', 'electric']}
# {'name': 'geodude', 'Primary type': 'ground', 'Secondary type': 'rock', 'Weaknesses': ['water', 'grass', 'ice', 'fighting', 'ground', 'steel', 'water', 'grass']}
# {'name': 'graveler', 'Primary type': 'ground', 'Secondary type': 'rock', 'Weaknesses': ['water', 'grass', 'ice', 'fighting', 'ground', 'steel', 'water', 'grass']}
# {'name': 'golem', 'Primary type': 'ground', 'Secondary type': 'rock', 'Weaknesses': ['water', 'grass', 'ice', 'fighting', 'ground', 'steel', 'water', 'grass']}
# {'name': 'ponyta', 'Primary type': 'fire', 'Secondary type': None, 'Weaknesses': ['ground', 'rock', 'water']}
# {'name': 'rapidash', 'Primary type': 'fire', 'Secondary type': None, 'Weaknesses': ['ground', 'rock', 'water']}
# {'name': 'slowpoke', 'Primary type': 'psychic', 'Secondary type': 'water', 'Weaknesses': ['bug', 'ghost', 'dark', 'grass', 'electric']}
# {'name': 'slowbro', 'Primary type': 'psychic', 'Secondary type': 'water', 'Weaknesses': ['bug', 'ghost', 'dark', 'grass', 'electric']}
# {'name': 'magnemite', 'Primary type': 'steel', 'Secondary type': 'electric', 'Weaknesses': ['fighting', 'ground', 'fire', 'ground']}
# {'name': 'magneton', 'Primary type': 'steel', 'Secondary type': 'electric', 'Weaknesses': ['fighting', 'ground', 'fire', 'ground']}
# {'name': 'farfetchd', 'Primary type': 'flying', 'Secondary type': 'normal', 'Weaknesses': ['rock', 'electric', 'ice', 'fighting']}
# {'name': 'doduo', 'Primary type': 'flying', 'Secondary type': 'normal', 'Weaknesses': ['rock', 'electric', 'ice', 'fighting']}
# {'name': 'dodrio', 'Primary type': 'flying', 'Secondary type': 'normal', 'Weaknesses': ['rock', 'electric', 'ice', 'fighting']}
# {'name': 'seel', 'Primary type': 'water', 'Secondary type': None, 'Weaknesses': ['grass', 'electric']}
# {'name': 'dewgong', 'Primary type': 'ice', 'Secondary type': 'water', 'Weaknesses': ['fighting', 'rock', 'steel', 'fire', 'grass', 'electric']}
# {'name': 'grimer', 'Primary type': 'poison', 'Secondary type': None, 'Weaknesses': ['ground', 'psychic']}
# {'name': 'muk', 'Primary type': 'poison', 'Secondary type': None, 'Weaknesses': ['ground', 'psychic']}
# {'name': 'shellder', 'Primary type': 'water', 'Secondary type': None, 'Weaknesses': ['grass', 'electric']}
# {'name': 'cloyster', 'Primary type': 'ice', 'Secondary type': 'water', 'Weaknesses': ['fighting', 'rock', 'steel', 'fire', 'grass', 'electric']}
# {'name': 'gastly', 'Primary type': 'poison', 'Secondary type': 'ghost', 'Weaknesses': ['ground', 'psychic', 'ghost', 'dark']}
# {'name': 'haunter', 'Primary type': 'poison', 'Secondary type': 'ghost', 'Weaknesses': ['ground', 'psychic', 'ghost', 'dark']}
# {'name': 'gengar', 'Primary type': 'poison', 'Secondary type': 'ghost', 'Weaknesses': ['ground', 'psychic', 'ghost', 'dark']}
# {'name': 'onix', 'Primary type': 'ground', 'Secondary type': 'rock', 'Weaknesses': ['water', 'grass', 'ice', 'fighting', 'ground', 'steel', 'water', 'grass']}
# {'name': 'drowzee', 'Primary type': 'psychic', 'Secondary type': None, 'Weaknesses': ['bug', 'ghost', 'dark']}
# {'name': 'hypno', 'Primary type': 'psychic', 'Secondary type': None, 'Weaknesses': ['bug', 'ghost', 'dark']}
# {'name': 'krabby', 'Primary type': 'water', 'Secondary type': None, 'Weaknesses': ['grass', 'electric']}
# {'name': 'kingler', 'Primary type': 'water', 'Secondary type': None, 'Weaknesses': ['grass', 'electric']}
# {'name': 'voltorb', 'Primary type': 'electric', 'Secondary type': None, 'Weaknesses': ['ground']}
# {'name': 'electrode', 'Primary type': 'electric', 'Secondary type': None, 'Weaknesses': ['ground']}
# {'name': 'exeggcute', 'Primary type': 'psychic', 'Secondary type': 'grass', 'Weaknesses': ['bug', 'ghost', 'dark', 'flying', 'poison', 'bug', 'fire', 'ice']}
# {'name': 'exeggutor', 'Primary type': 'psychic', 'Secondary type': 'grass', 'Weaknesses': ['bug', 'ghost', 'dark', 'flying', 'poison', 'bug', 'fire', 'ice']}
# {'name': 'cubone', 'Primary type': 'ground', 'Secondary type': None, 'Weaknesses': ['water', 'grass', 'ice']}
# {'name': 'marowak', 'Primary type': 'ground', 'Secondary type': None, 'Weaknesses': ['water', 'grass', 'ice']}
# {'name': 'hitmonlee', 'Primary type': 'fighting', 'Secondary type': None, 'Weaknesses': ['flying', 'psychic', 'fairy']}
# {'name': 'hitmonchan', 'Primary type': 'fighting', 'Secondary type': None, 'Weaknesses': ['flying', 'psychic', 'fairy']}
# {'name': 'lickitung', 'Primary type': 'normal', 'Secondary type': None, 'Weaknesses': ['fighting']}
# {'name': 'koffing', 'Primary type': 'poison', 'Secondary type': None, 'Weaknesses': ['ground', 'psychic']}
# {'name': 'weezing', 'Primary type': 'poison', 'Secondary type': None, 'Weaknesses': ['ground', 'psychic']}
# {'name': 'rhyhorn', 'Primary type': 'rock', 'Secondary type': 'ground', 'Weaknesses': ['fighting', 'ground', 'steel', 'water', 'grass', 'water', 'grass', 'ice']}
# {'name': 'rhydon', 'Primary type': 'rock', 'Secondary type': 'ground', 'Weaknesses': ['fighting', 'ground', 'steel', 'water', 'grass', 'water', 'grass', 'ice']}
# {'name': 'chansey', 'Primary type': 'normal', 'Secondary type': None, 'Weaknesses': ['fighting']}
# {'name': 'tangela', 'Primary type': 'grass', 'Secondary type': None, 'Weaknesses': ['flying', 'poison', 'bug', 'fire', 'ice']}
# {'name': 'kangaskhan', 'Primary type': 'normal', 'Secondary type': None, 'Weaknesses': ['fighting']}
# {'name': 'horsea', 'Primary type': 'water', 'Secondary type': None, 'Weaknesses': ['grass', 'electric']}
# {'name': 'seadra', 'Primary type': 'water', 'Secondary type': None, 'Weaknesses': ['grass', 'electric']}
# {'name': 'goldeen', 'Primary type': 'water', 'Secondary type': None, 'Weaknesses': ['grass', 'electric']}
# {'name': 'seaking', 'Primary type': 'water', 'Secondary type': None, 'Weaknesses': ['grass', 'electric']}
# {'name': 'staryu', 'Primary type': 'water', 'Secondary type': None, 'Weaknesses': ['grass', 'electric']}
# {'name': 'starmie', 'Primary type': 'psychic', 'Secondary type': 'water', 'Weaknesses': ['bug', 'ghost', 'dark', 'grass', 'electric']}
# {'name': 'mr-mime', 'Primary type': 'fairy', 'Secondary type': 'psychic', 'Weaknesses': ['poison', 'steel', 'bug', 'ghost', 'dark']}
# {'name': 'scyther', 'Primary type': 'flying', 'Secondary type': 'bug', 'Weaknesses': ['rock', 'electric', 'ice', 'flying', 'rock', 'fire']}
# {'name': 'jynx', 'Primary type': 'psychic', 'Secondary type': 'ice', 'Weaknesses': ['bug', 'ghost', 'dark', 'fighting', 'rock', 'steel', 'fire']}
# {'name': 'electabuzz', 'Primary type': 'electric', 'Secondary type': None, 'Weaknesses': ['ground']}
# {'name': 'magmar', 'Primary type': 'fire', 'Secondary type': None, 'Weaknesses': ['ground', 'rock', 'water']}
# {'name': 'pinsir', 'Primary type': 'bug', 'Secondary type': None, 'Weaknesses': ['flying', 'rock', 'fire']}
# {'name': 'tauros', 'Primary type': 'normal', 'Secondary type': None, 'Weaknesses': ['fighting']}
# {'name': 'magikarp', 'Primary type': 'water', 'Secondary type': None, 'Weaknesses': ['grass', 'electric']}
# {'name': 'gyarados', 'Primary type': 'flying', 'Secondary type': 'water', 'Weaknesses': ['rock', 'electric', 'ice', 'grass', 'electric']}
# {'name': 'lapras', 'Primary type': 'ice', 'Secondary type': 'water', 'Weaknesses': ['fighting', 'rock', 'steel', 'fire', 'grass', 'electric']}
# {'name': 'ditto', 'Primary type': 'normal', 'Secondary type': None, 'Weaknesses': ['fighting']}
# {'name': 'eevee', 'Primary type': 'normal', 'Secondary type': None, 'Weaknesses': ['fighting']}
# {'name': 'vaporeon', 'Primary type': 'water', 'Secondary type': None, 'Weaknesses': ['grass', 'electric']}
# {'name': 'jolteon', 'Primary type': 'electric', 'Secondary type': None, 'Weaknesses': ['ground']}
# {'name': 'flareon', 'Primary type': 'fire', 'Secondary type': None, 'Weaknesses': ['ground', 'rock', 'water']}
# {'name': 'porygon', 'Primary type': 'normal', 'Secondary type': None, 'Weaknesses': ['fighting']}
# {'name': 'omanyte', 'Primary type': 'water', 'Secondary type': 'rock', 'Weaknesses': ['grass', 'electric', 'fighting', 'ground', 'steel', 'water', 'grass']}
# {'name': 'omastar', 'Primary type': 'water', 'Secondary type': 'rock', 'Weaknesses': ['grass', 'electric', 'fighting', 'ground', 'steel', 'water', 'grass']}
# {'name': 'kabuto', 'Primary type': 'water', 'Secondary type': 'rock', 'Weaknesses': ['grass', 'electric', 'fighting', 'ground', 'steel', 'water', 'grass']}
# {'name': 'kabutops', 'Primary type': 'water', 'Secondary type': 'rock', 'Weaknesses': ['grass', 'electric', 'fighting', 'ground', 'steel', 'water', 'grass']}
# {'name': 'aerodactyl', 'Primary type': 'flying', 'Secondary type': 'rock', 'Weaknesses': ['rock', 'electric', 'ice', 'fighting', 'ground', 'steel', 'water', 'grass']}
# {'name': 'snorlax', 'Primary type': 'normal', 'Secondary type': None, 'Weaknesses': ['fighting']}
# {'name': 'articuno', 'Primary type': 'flying', 'Secondary type': 'ice', 'Weaknesses': ['rock', 'electric', 'ice', 'fighting', 'rock', 'steel', 'fire']}
# {'name': 'zapdos', 'Primary type': 'flying', 'Secondary type': 'electric', 'Weaknesses': ['rock', 'electric', 'ice', 'ground']}
# {'name': 'moltres', 'Primary type': 'flying', 'Secondary type': 'fire', 'Weaknesses': ['rock', 'electric', 'ice', 'ground', 'rock', 'water']}
# {'name': 'dratini', 'Primary type': 'dragon', 'Secondary type': None, 'Weaknesses': ['ice', 'dragon', 'fairy']}
# {'name': 'dragonair', 'Primary type': 'dragon', 'Secondary type': None, 'Weaknesses': ['ice', 'dragon', 'fairy']}
# {'name': 'dragonite', 'Primary type': 'flying', 'Secondary type': 'dragon', 'Weaknesses': ['rock', 'electric', 'ice', 'ice', 'dragon', 'fairy']}
# {'name': 'mewtwo', 'Primary type': 'psychic', 'Secondary type': None, 'Weaknesses': ['bug', 'ghost', 'dark']}
# {'name': 'mew', 'Primary type': 'psychic', 'Secondary type': None, 'Weaknesses': ['bug', 'ghost', 'dark']}

# %% [markdown]
# # <center> Bonus

# %% [markdown]
# ### Mongo Queries

# %% [markdown]
# If you finish early, try to solve these questions using queries. Here are some links that might be helpful:
# - https://docs.mongodb.com/manual/reference/operator/query/#query-selectors
# - https://api.mongodb.com/python/current/api/pymongo/cursor.html#pymongo.cursor.Cursor.sort
# - https://api.mongodb.com/python/current/examples/aggregation.html

# %% [markdown]
# What are the top 5 tallest Pokemon?

# %% [markdown]
# What are the top 5 lightest Pokemon?

# %% [markdown]
# What Pokemon are weak to Ghost type attacks?

# %% [markdown]
# What Pokemon has the most number of weaknesses?
